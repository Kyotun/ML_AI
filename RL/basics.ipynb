# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ### Load the Environment

# %%
environment = 'CartPole-v1'
env = gym.make(environment, render_mode="human")

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset() #Initial set of observations
    done = False 
    score = 0
    
    while not done:
        env.render() #View the graphical representation of environment
        action = env.action_space.sample()#Generate random actions
        # Two actions possible -> push left / right
        
        # env.observation_space
        # Observation_space -> Position, Velocity of Cart ; Pole Angle and Agular Velocity
        # These make 4 info, in other words Box(4)
        
        n_state, reward, done, info , extra_info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score:48.0
# Episode:2 Score:43.0
# Episode:3 Score:12.0
# Episode:4 Score:52.0
# Episode:5 Score:27.0

# %%
#Create/Make the directories
log_path = os.path.join('Training', 'Logs')
log_path
# Out:
# 'Training/Logs'

# %%
env = gym.make(environment)
#Wrapped the environment inside the DummyVecEnv
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# /Users/kyotun/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
#Timesteps depend on the complexity of the environment
model.learn(total_timesteps=200000)
# Out:
# Logging to Training/Logs/PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 6275 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4093        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009183841 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00161     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.49        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 49          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3690        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009797019 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 33.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3505        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008245634 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.628      |
# |    explained_variance   | 0.189       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 56.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3399         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0061653852 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | 0.25         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.6         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0172      |
# |    value_loss           | 64.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3263        |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.007571578 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.496       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 55.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3192        |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006697966 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.625       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00762    |
# |    value_loss           | 44.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3150         |
# |    iterations           | 8            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0063742087 |
# |    clip_fraction        | 0.0516       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.587       |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.15         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00688     |
# |    value_loss           | 27.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3113         |
# |    iterations           | 9            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0040810946 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.844        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.2         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00548     |
# |    value_loss           | 35.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3090         |
# |    iterations           | 10           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0021698766 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.552       |
# |    explained_variance   | 0.723        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.6         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 35.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3067        |
# |    iterations           | 11          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.004474734 |
# |    clip_fraction        | 0.0502      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.55       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.42        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00792    |
# |    value_loss           | 29.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3051        |
# |    iterations           | 12          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008723057 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.545      |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.236       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00958    |
# |    value_loss           | 6.81        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3020         |
# |    iterations           | 13           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0070695104 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.526       |
# |    explained_variance   | 0.641        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.322        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00474     |
# |    value_loss           | 4.59         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3015         |
# |    iterations           | 14           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0038545066 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.535       |
# |    explained_variance   | 0.213        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.188        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 2.89         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3015        |
# |    iterations           | 15          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008538034 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | 0.267       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0716      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00323    |
# |    value_loss           | 1.78        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3016        |
# |    iterations           | 16          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005675224 |
# |    clip_fraction        | 0.0539      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.513      |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000903   |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00407    |
# |    value_loss           | 1.18        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3019        |
# |    iterations           | 17          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.004053319 |
# |    clip_fraction        | 0.0397      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.504      |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0609      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00767    |
# |    value_loss           | 0.749       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3017         |
# |    iterations           | 18           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0015033254 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.0521       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0372       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000749    |
# |    value_loss           | 0.406        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3020         |
# |    iterations           | 19           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0029828867 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.498       |
# |    explained_variance   | 0.0184       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0264       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 0.266        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3021         |
# |    iterations           | 20           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0025593112 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.484       |
# |    explained_variance   | -0.0165      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0334       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000211    |
# |    value_loss           | 0.164        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3017         |
# |    iterations           | 21           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0023149692 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.489       |
# |    explained_variance   | 0.0602       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00219     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 0.0989       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3013        |
# |    iterations           | 22          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005038853 |
# |    clip_fraction        | 0.0534      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | 0.0342      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0195     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 0.0614      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3009         |
# |    iterations           | 23           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0056013195 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.478       |
# |    explained_variance   | 0.0089       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00456     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 0.0389       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3004         |
# |    iterations           | 24           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0011571007 |
# |    clip_fraction        | 0.00869      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.48        |
# |    explained_variance   | -0.0326      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000237     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -8.5e-05     |
# |    value_loss           | 0.025        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2999         |
# |    iterations           | 25           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0033311557 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | -0.00451     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00619     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 0.0153       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2990        |
# |    iterations           | 26          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.004520349 |
# |    clip_fraction        | 0.0206      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.496      |
# |    explained_variance   | -0.015      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00732     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.000791   |
# |    value_loss           | 0.0107      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2982         |
# |    iterations           | 27           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0030807122 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.462       |
# |    explained_variance   | -0.0142      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000829    |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 0.00659      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2985        |
# |    iterations           | 28          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.003571635 |
# |    clip_fraction        | 0.0202      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.467      |
# |    explained_variance   | -0.0613     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00287     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.000167   |
# |    value_loss           | 0.00447     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2989         |
# |    iterations           | 29           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0021375832 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.47        |
# |    explained_variance   | -0.0279      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00291     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.000239    |
# |    value_loss           | 0.00299      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2991         |
# |    iterations           | 30           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0043547135 |
# |    clip_fraction        | 0.0695       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.471       |
# |    explained_variance   | -0.000368    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00656      |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 0.0021       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2989         |
# |    iterations           | 31           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0053538783 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.456       |
# |    explained_variance   | -0.0276      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00895      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 0.00141      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2991         |
# |    iterations           | 32           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0062524104 |
# |    clip_fraction        | 0.0757       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.453       |
# |    explained_variance   | 0.0327       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00296     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00277     |
# |    value_loss           | 0.000894     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2992        |
# |    iterations           | 33          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007267578 |
# |    clip_fraction        | 0.0763      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.46       |
# |    explained_variance   | 0.125       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00347     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00562    |
# |    value_loss           | 0.000633    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2994        |
# |    iterations           | 34          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.006187672 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.462      |
# |    explained_variance   | -0.0471     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000423    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 0.000424    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2997         |
# |    iterations           | 35           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0036291052 |
# |    clip_fraction        | 0.0463       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.457       |
# |    explained_variance   | 0.0398       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0158      |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00239     |
# |    value_loss           | 0.000307     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2997         |
# |    iterations           | 36           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0065437728 |
# |    clip_fraction        | 0.0731       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.453       |
# |    explained_variance   | 0.0507       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.015        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00438     |
# |    value_loss           | 0.00022      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3000        |
# |    iterations           | 37          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.005789113 |
# |    clip_fraction        | 0.0461      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.452      |
# |    explained_variance   | -0.0839     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0121      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.000957   |
# |    value_loss           | 0.000164    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3002        |
# |    iterations           | 38          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004923181 |
# |    clip_fraction        | 0.0591      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.446      |
# |    explained_variance   | -0.0652     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0201      |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00268    |
# |    value_loss           | 0.000115    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3004         |
# |    iterations           | 39           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0080534285 |
# |    clip_fraction        | 0.0567       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.444       |
# |    explained_variance   | -0.0779      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00478      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 7.86e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3005        |
# |    iterations           | 40          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.004972046 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.452      |
# |    explained_variance   | -0.166      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000684    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00028    |
# |    value_loss           | 6.07e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3007         |
# |    iterations           | 41           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0044013862 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.448       |
# |    explained_variance   | -0.158       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.015        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 5.1e-05      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3009        |
# |    iterations           | 42          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006442371 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.448      |
# |    explained_variance   | -0.169      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00883    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00405    |
# |    value_loss           | 3.12e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3011        |
# |    iterations           | 43          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004176392 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.427      |
# |    explained_variance   | -0.165      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0044     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 2.12e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3014         |
# |    iterations           | 44           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0029310947 |
# |    clip_fraction        | 0.025        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.411       |
# |    explained_variance   | -0.376       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0129      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 1.66e-05     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3017       |
# |    iterations           | 45         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00270451 |
# |    clip_fraction        | 0.0197     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.411     |
# |    explained_variance   | -0.531     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00252    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00137   |
# |    value_loss           | 1.31e-05   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3020         |
# |    iterations           | 46           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0013634507 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.405       |
# |    explained_variance   | -0.609       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0102       |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00138     |
# |    value_loss           | 8.3e-06      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3022        |
# |    iterations           | 47          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004010434 |
# |    clip_fraction        | 0.0441      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.383      |
# |    explained_variance   | -0.523      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00952     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00361    |
# |    value_loss           | 6.1e-06     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3022         |
# |    iterations           | 48           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0022235056 |
# |    clip_fraction        | 0.0252       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.378       |
# |    explained_variance   | -0.846       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00147     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000645    |
# |    value_loss           | 6.16e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3022         |
# |    iterations           | 49           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0041260845 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.344       |
# |    explained_variance   | -0.709       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00304      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00229     |
# |    value_loss           | 3.53e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3022         |
# |    iterations           | 50           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0018542795 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.335       |
# |    explained_variance   | -1.24        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00297      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000231    |
# |    value_loss           | 3.94e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3023        |
# |    iterations           | 51          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.002492657 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.328      |
# |    explained_variance   | -0.419      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0026     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.000704   |
# |    value_loss           | 6.11e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3024         |
# |    iterations           | 52           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0036081118 |
# |    clip_fraction        | 0.0241       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.321       |
# |    explained_variance   | -1.69        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00462      |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.000894    |
# |    value_loss           | 2.84e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3025         |
# |    iterations           | 53           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0018386862 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.316       |
# |    explained_variance   | -1.54        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0023       |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0004      |
# |    value_loss           | 3.64e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3026         |
# |    iterations           | 54           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0025276854 |
# |    clip_fraction        | 0.019        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.277       |
# |    explained_variance   | -1.42        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00416      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 1.65e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3028         |
# |    iterations           | 55           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0011918203 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.28        |
# |    explained_variance   | -1.71        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00553      |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.000809    |
# |    value_loss           | 1.58e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3029        |
# |    iterations           | 56          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.002888357 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.278      |
# |    explained_variance   | -2.72       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000445   |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00073    |
# |    value_loss           | 1.71e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3030        |
# |    iterations           | 57          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.001244974 |
# |    clip_fraction        | 0.0244      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.276      |
# |    explained_variance   | -2.2        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000745   |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.000859   |
# |    value_loss           | 2.32e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3031        |
# |    iterations           | 58          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.005743818 |
# |    clip_fraction        | 0.0289      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.277      |
# |    explained_variance   | -5.59       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000711    |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.000379   |
# |    value_loss           | 7.84e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3033         |
# |    iterations           | 59           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0035864103 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.264       |
# |    explained_variance   | -1.1         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00645      |
# |    n_updates            | 580          |
# |    policy_gradient_loss | 0.000632     |
# |    value_loss           | 9.51e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3033         |
# |    iterations           | 60           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0027991799 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | -3.57        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00398     |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.00115     |
# |    value_loss           | 1.13e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3031        |
# |    iterations           | 61          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.004096525 |
# |    clip_fraction        | 0.022       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.235      |
# |    explained_variance   | -0.902      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00182    |
# |    n_updates            | 600         |
# |    policy_gradient_loss | 0.000275    |
# |    value_loss           | 7.56e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3030         |
# |    iterations           | 62           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0011633248 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | -1.18        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000821    |
# |    n_updates            | 610          |
# |    policy_gradient_loss | 0.000792     |
# |    value_loss           | 7.22e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3030         |
# |    iterations           | 63           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 129024       |
# | train/                  |              |
# |    approx_kl            | 0.0014834534 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.238       |
# |    explained_variance   | -3.39        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00388     |
# |    n_updates            | 620          |
# |    policy_gradient_loss | 0.000133     |
# |    value_loss           | 5e-06        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3027         |
# |    iterations           | 64           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 131072       |
# ...
# |    time_elapsed         | 52           |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0017626351 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.264       |
# |    explained_variance   | -1.96        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00157     |
# |    n_updates            | 770          |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 3.58e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3017         |
# |    iterations           | 79           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 161792       |
# | train/                  |              |
# |    approx_kl            | 0.0075113717 |
# |    clip_fraction        | 0.0772       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.265       |
# |    explained_variance   | -1.48        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0108      |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00367     |
# |    value_loss           | 9.61e-07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3018          |
# |    iterations           | 80            |
# |    time_elapsed         | 54            |
# |    total_timesteps      | 163840        |
# | train/                  |               |
# |    approx_kl            | 0.00062320975 |
# |    clip_fraction        | 0.00781       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.266        |
# |    explained_variance   | -0.81         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00411      |
# |    n_updates            | 790           |
# |    policy_gradient_loss | -8.79e-05     |
# |    value_loss           | 8.5e-06       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3018         |
# |    iterations           | 81           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0012137278 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.278       |
# |    explained_variance   | -1.12        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00352     |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.000684    |
# |    value_loss           | 2.6e-07      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3016         |
# |    iterations           | 82           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0044400385 |
# |    clip_fraction        | 0.0481       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.259       |
# |    explained_variance   | -0.938       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0141      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00397     |
# |    value_loss           | 2.53e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3015        |
# |    iterations           | 83          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.001211143 |
# |    clip_fraction        | 0.00591     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.252      |
# |    explained_variance   | -0.908      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000654    |
# |    n_updates            | 820         |
# |    policy_gradient_loss | 0.000312    |
# |    value_loss           | 1.43e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3015        |
# |    iterations           | 84          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.004842965 |
# |    clip_fraction        | 0.0535      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.272      |
# |    explained_variance   | -1.02       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00806    |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00254    |
# |    value_loss           | 7.12e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3014         |
# |    iterations           | 85           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0011965693 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.262       |
# |    explained_variance   | -2.24        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00173     |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.000682    |
# |    value_loss           | 3.25e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3013         |
# |    iterations           | 86           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0011054052 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.272       |
# |    explained_variance   | -2.38        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00833     |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -8.47e-05    |
# |    value_loss           | 7.38e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3013         |
# |    iterations           | 87           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0010783399 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.266       |
# |    explained_variance   | -1.67        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00579     |
# |    n_updates            | 860          |
# |    policy_gradient_loss | 6.24e-07     |
# |    value_loss           | 1e-05        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3011         |
# |    iterations           | 88           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0010081064 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.265       |
# |    explained_variance   | -1.86        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0056      |
# |    n_updates            | 870          |
# |    policy_gradient_loss | 0.00017      |
# |    value_loss           | 2.71e-06     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3012       |
# |    iterations           | 89         |
# |    time_elapsed         | 60         |
# |    total_timesteps      | 182272     |
# | train/                  |            |
# |    approx_kl            | 0.00302606 |
# |    clip_fraction        | 0.0202     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.255     |
# |    explained_variance   | -1.87      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00761   |
# |    n_updates            | 880        |
# |    policy_gradient_loss | -0.00368   |
# |    value_loss           | 4.04e-07   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3013         |
# |    iterations           | 90           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0037065702 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.261       |
# |    explained_variance   | -2.08        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000675    |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 1.34e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3014         |
# |    iterations           | 91           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0021632467 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | -1.66        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000355    |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.000139    |
# |    value_loss           | 7.28e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3014         |
# |    iterations           | 92           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0023134935 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.25        |
# |    explained_variance   | -2.42        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00171      |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.000569    |
# |    value_loss           | 3.76e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3015         |
# |    iterations           | 93           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0012989995 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.257       |
# |    explained_variance   | -2.45        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00231     |
# |    n_updates            | 920          |
# |    policy_gradient_loss | 0.000271     |
# |    value_loss           | 1.65e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3016        |
# |    iterations           | 94          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.006506188 |
# |    clip_fraction        | 0.0746      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.262      |
# |    explained_variance   | -1.26       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00292     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00608    |
# |    value_loss           | 2.92e-07    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3017       |
# |    iterations           | 95         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 194560     |
# | train/                  |            |
# |    approx_kl            | 0.00476305 |
# |    clip_fraction        | 0.0409     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.268     |
# |    explained_variance   | -0.853     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00542    |
# |    n_updates            | 940        |
# |    policy_gradient_loss | -0.00247   |
# |    value_loss           | 9.99e-06   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3017         |
# |    iterations           | 96           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0038687512 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.259       |
# |    explained_variance   | -2.38        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0111       |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.000366    |
# |    value_loss           | 2.71e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3016         |
# |    iterations           | 97           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0048457393 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.268       |
# |    explained_variance   | -1.91        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0237      |
# |    n_updates            | 960          |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 2.45e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3015         |
# |    iterations           | 98           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0014504392 |
# |    clip_fraction        | 0.00874      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.268       |
# |    explained_variance   | -2.36        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00581      |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.000205    |
# |    value_loss           | 3.32e-07     |
# ------------------------------------------

# %% [markdown]
# ### Save and Reload Model

# %%
PPO_Path = os.path.join('Training', 'Saved Models', 'PPO_Model_Cartpole')

# %%
model.save(PPO_Path)

# %%
#Delete the model and reload it
del model

# %%
model = PPO.load(PPO_Path, env=env)

# %%
model.learn(total_timesteps=200000)
# Out:
# Logging to Training/Logs/PPO_2
# -----------------------------
# | time/              |      |
# |    fps             | 6174 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3934         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0017033794 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.28        |
# |    explained_variance   | -1.81        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00894     |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 4.2e-07      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3536         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0028493279 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.262       |
# |    explained_variance   | -1.58        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00586     |
# |    n_updates            | 1000         |
# |    policy_gradient_loss | -0.000706    |
# |    value_loss           | 7.47e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3362         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0050969087 |
# |    clip_fraction        | 0.0647       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.271       |
# |    explained_variance   | -2.05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00835     |
# |    n_updates            | 1010         |
# |    policy_gradient_loss | -0.00409     |
# |    value_loss           | 7.56e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3262         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0010495305 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.276       |
# |    explained_variance   | -2.49        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00259     |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | -0.000538    |
# |    value_loss           | 1.53e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3231        |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.003241957 |
# |    clip_fraction        | 0.0343      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.272      |
# |    explained_variance   | -2.15       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000744   |
# |    n_updates            | 1030        |
# |    policy_gradient_loss | -7.98e-06   |
# |    value_loss           | 3.71e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3186         |
# |    iterations           | 7            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0016425869 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.271       |
# |    explained_variance   | -3.08        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00142      |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 2.15e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3139        |
# |    iterations           | 8           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005737044 |
# |    clip_fraction        | 0.0361      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.259      |
# |    explained_variance   | -3.18       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00519     |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.0015     |
# |    value_loss           | 7.83e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3114         |
# |    iterations           | 9            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0053861104 |
# |    clip_fraction        | 0.0429       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.268       |
# |    explained_variance   | -1.48        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00525      |
# |    n_updates            | 1060         |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 2.45e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3096         |
# |    iterations           | 10           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0024819039 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.272       |
# |    explained_variance   | -3.35        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00138      |
# |    n_updates            | 1070         |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 2.45e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3077        |
# |    iterations           | 11          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.003258876 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.26       |
# |    explained_variance   | -0.909      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00168    |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | -0.000798   |
# |    value_loss           | 2.64e-07    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3067          |
# |    iterations           | 12            |
# |    time_elapsed         | 8             |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00076536287 |
# |    clip_fraction        | 0.0189        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.289        |
# |    explained_variance   | -1.82         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00281      |
# |    n_updates            | 1090          |
# |    policy_gradient_loss | 0.000193      |
# |    value_loss           | 1.04e-06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3053         |
# |    iterations           | 13           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0020543057 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.261       |
# |    explained_variance   | -1.38        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00273     |
# |    n_updates            | 1100         |
# |    policy_gradient_loss | 3.03e-06     |
# |    value_loss           | 1.59e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3032         |
# |    iterations           | 14           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0050440254 |
# |    clip_fraction        | 0.0632       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.277       |
# |    explained_variance   | -2.22        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0033       |
# |    n_updates            | 1110         |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 1.07e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3010         |
# |    iterations           | 15           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0006552767 |
# |    clip_fraction        | 0.00571      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.279       |
# |    explained_variance   | -1.9         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00331     |
# |    n_updates            | 1120         |
# |    policy_gradient_loss | -0.00023     |
# |    value_loss           | 5.07e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3000         |
# |    iterations           | 16           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0041601574 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.27        |
# |    explained_variance   | -2.65        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00188      |
# |    n_updates            | 1130         |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 1.79e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2992         |
# |    iterations           | 17           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0013882314 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | -1.04        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.68e-05     |
# |    n_updates            | 1140         |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 9e-06        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2984         |
# |    iterations           | 18           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0021149446 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.245       |
# |    explained_variance   | -0.509       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000682    |
# |    n_updates            | 1150         |
# |    policy_gradient_loss | -6.57e-05    |
# |    value_loss           | 1.1e-07      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2977         |
# |    iterations           | 19           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0019067611 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | -0.689       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00132      |
# |    n_updates            | 1160         |
# |    policy_gradient_loss | 0.0001       |
# |    value_loss           | 1.6e-06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2972         |
# |    iterations           | 20           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0014484549 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.256       |
# |    explained_variance   | -0.601       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00856      |
# |    n_updates            | 1170         |
# |    policy_gradient_loss | -0.000236    |
# |    value_loss           | 1.21e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2969         |
# |    iterations           | 21           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0025355301 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | -0.693       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00191      |
# |    n_updates            | 1180         |
# |    policy_gradient_loss | -0.00041     |
# |    value_loss           | 1.26e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2961         |
# |    iterations           | 22           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0038878422 |
# |    clip_fraction        | 0.0275       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | -1.19        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0121       |
# |    n_updates            | 1190         |
# |    policy_gradient_loss | -0.000677    |
# |    value_loss           | 1.66e-06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2954          |
# |    iterations           | 23            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00041622738 |
# |    clip_fraction        | 0.0179        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.246        |
# |    explained_variance   | -0.754        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00271      |
# |    n_updates            | 1200          |
# |    policy_gradient_loss | 0.000299      |
# |    value_loss           | 6.04e-06      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2955         |
# |    iterations           | 24           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0033373167 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.256       |
# |    explained_variance   | -1.91        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00567     |
# |    n_updates            | 1210         |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 1.97e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2956         |
# |    iterations           | 25           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0040440923 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.263       |
# |    explained_variance   | -1.24        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00192     |
# |    n_updates            | 1220         |
# |    policy_gradient_loss | 9.67e-05     |
# |    value_loss           | 6.22e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2957         |
# |    iterations           | 26           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0011125843 |
# |    clip_fraction        | 0.0159       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.242       |
# |    explained_variance   | -2.7         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00615      |
# |    n_updates            | 1230         |
# |    policy_gradient_loss | 9.2e-05      |
# |    value_loss           | 1.03e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2956         |
# |    iterations           | 27           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0026441878 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.258       |
# |    explained_variance   | -1.53        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00144     |
# |    n_updates            | 1240         |
# |    policy_gradient_loss | -0.000532    |
# |    value_loss           | 9.63e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2954         |
# |    iterations           | 28           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0026904936 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | -2.57        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00594      |
# |    n_updates            | 1250         |
# |    policy_gradient_loss | -0.000549    |
# |    value_loss           | 1.08e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2953         |
# |    iterations           | 29           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0013416762 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.235       |
# |    explained_variance   | -2.3         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00273     |
# |    n_updates            | 1260         |
# |    policy_gradient_loss | -0.000371    |
# |    value_loss           | 9.88e-08     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2950        |
# |    iterations           | 30          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.002149717 |
# |    clip_fraction        | 0.031       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.267      |
# |    explained_variance   | -3.6        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000237   |
# |    n_updates            | 1270        |
# |    policy_gradient_loss | 3.49e-05    |
# |    value_loss           | 1.28e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2949        |
# |    iterations           | 31          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.005748342 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.274      |
# |    explained_variance   | -2.45       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00913    |
# |    n_updates            | 1280        |
# |    policy_gradient_loss | -0.00286    |
# |    value_loss           | 1.61e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2947         |
# |    iterations           | 32           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0017711094 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.262       |
# |    explained_variance   | -1.88        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00474      |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | -0.000245    |
# |    value_loss           | 1.58e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2945         |
# |    iterations           | 33           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0014520274 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.244       |
# |    explained_variance   | -1.84        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00564     |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | -0.000517    |
# |    value_loss           | 1.44e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2943         |
# |    iterations           | 34           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0015159061 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | -1.11        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0187      |
# |    n_updates            | 1310         |
# |    policy_gradient_loss | -0.00276     |
# |    value_loss           | 2.78e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2945         |
# |    iterations           | 35           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0019048969 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.258       |
# |    explained_variance   | -1.07        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00479     |
# |    n_updates            | 1320         |
# |    policy_gradient_loss | 0.000771     |
# |    value_loss           | 5.72e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2947         |
# |    iterations           | 36           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0034228633 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.273       |
# |    explained_variance   | -4.02        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00264     |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | 0.000145     |
# |    value_loss           | 1.22e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2949        |
# |    iterations           | 37          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.005025102 |
# |    clip_fraction        | 0.0255      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.251      |
# |    explained_variance   | -1          |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000329   |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | -0.00241    |
# |    value_loss           | 6.3e-06     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2952       |
# |    iterations           | 38         |
# |    time_elapsed         | 26         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.00525572 |
# |    clip_fraction        | 0.0573     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.269     |
# |    explained_variance   | -1.89      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00357    |
# |    n_updates            | 1350       |
# |    policy_gradient_loss | -0.00303   |
# |    value_loss           | 1.35e-06   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2953         |
# |    iterations           | 39           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0016522843 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.253       |
# |    explained_variance   | -1.24        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0024       |
# |    n_updates            | 1360         |
# |    policy_gradient_loss | 0.000694     |
# |    value_loss           | 3.42e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2954         |
# |    iterations           | 40           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0014257538 |
# |    clip_fraction        | 0.0116       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.234       |
# |    explained_variance   | -1.26        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000116    |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 2.04e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2954         |
# |    iterations           | 41           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0045087887 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.241       |
# |    explained_variance   | -1.02        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00101     |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 4.19e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2953         |
# |    iterations           | 42           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0014987233 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.25        |
# |    explained_variance   | -0.55        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00789      |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.000101    |
# |    value_loss           | 4.26e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2952         |
# |    iterations           | 43           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0011569486 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.258       |
# |    explained_variance   | -0.814       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00148     |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | 0.000568     |
# |    value_loss           | 5.74e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2952        |
# |    iterations           | 44          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.003218961 |
# |    clip_fraction        | 0.0182      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.259      |
# |    explained_variance   | -0.941      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00414    |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.000319   |
# |    value_loss           | 1.08e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2952         |
# |    iterations           | 45           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0020366246 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.266       |
# |    explained_variance   | -2.81        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00155     |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | -0.000935    |
# |    value_loss           | 8.66e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2949         |
# |    iterations           | 46           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0020959973 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.277       |
# |    explained_variance   | -3.44        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00311      |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | -9.71e-05    |
# |    value_loss           | 9.63e-08     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2948        |
# |    iterations           | 47          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.002120818 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.275      |
# |    explained_variance   | -2.18       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0138     |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | 0.000602    |
# |    value_loss           | 1.18e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2947         |
# |    iterations           | 48           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0036967963 |
# |    clip_fraction        | 0.0591       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.273       |
# |    explained_variance   | -2.33        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00448     |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | -0.00412     |
# |    value_loss           | 1.64e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2948         |
# |    iterations           | 49           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0027864622 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.27        |
# |    explained_variance   | -1.27        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00272     |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | 0.000747     |
# |    value_loss           | 5.81e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2950         |
# |    iterations           | 50           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0032554609 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.271       |
# |    explained_variance   | -1.03        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00302     |
# |    n_updates            | 1470         |
# |    policy_gradient_loss | -0.000158    |
# |    value_loss           | 4.28e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2951        |
# |    iterations           | 51          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.002491578 |
# |    clip_fraction        | 0.0278      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.293      |
# |    explained_variance   | -1.25       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0114      |
# |    n_updates            | 1480        |
# |    policy_gradient_loss | 8.92e-05    |
# |    value_loss           | 1.92e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2951         |
# |    iterations           | 52           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0005985048 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.276       |
# |    explained_variance   | -3.38        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00152     |
# |    n_updates            | 1490         |
# |    policy_gradient_loss | -0.000412    |
# |    value_loss           | 8.54e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2952        |
# |    iterations           | 53          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.001328788 |
# |    clip_fraction        | 0.0132      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.267      |
# |    explained_variance   | -1.75       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00119    |
# |    n_updates            | 1500        |
# |    policy_gradient_loss | -4.79e-05   |
# |    value_loss           | 8.18e-08    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2953          |
# |    iterations           | 54            |
# |    time_elapsed         | 37            |
# |    total_timesteps      | 110592        |
# | train/                  |               |
# |    approx_kl            | 0.00079955487 |
# |    clip_fraction        | 0.013         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.265        |
# |    explained_variance   | -1.5          |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00358      |
# |    n_updates            | 1510          |
# |    policy_gradient_loss | 9.69e-05      |
# |    value_loss           | 1.19e-07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2954         |
# |    iterations           | 55           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0022422955 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.262       |
# |    explained_variance   | -2.41        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000824     |
# |    n_updates            | 1520         |
# |    policy_gradient_loss | -0.000567    |
# |    value_loss           | 1.58e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2955         |
# |    iterations           | 56           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0008616387 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.245       |
# |    explained_variance   | -2.15        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00187      |
# |    n_updates            | 1530         |
# |    policy_gradient_loss | -0.000434    |
# |    value_loss           | 2.88e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2954         |
# |    iterations           | 57           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0007628101 |
# |    clip_fraction        | 0.00864      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | -0.634       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00247     |
# |    n_updates            | 1540         |
# |    policy_gradient_loss | 0.00033      |
# |    value_loss           | 7.73e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2954         |
# |    iterations           | 58           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0025597638 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.25        |
# |    explained_variance   | -1.51        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00145     |
# |    n_updates            | 1550         |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 1.22e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2953         |
# |    iterations           | 59           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0027483497 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.27        |
# |    explained_variance   | -0.616       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -5.05e-05    |
# |    n_updates            | 1560         |
# |    policy_gradient_loss | 9.99e-05     |
# |    value_loss           | 1.15e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2952        |
# |    iterations           | 60          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.000881711 |
# |    clip_fraction        | 0.00957     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.253      |
# |    explained_variance   | -1.93       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00105    |
# |    n_updates            | 1570        |
# |    policy_gradient_loss | 0.000207    |
# |    value_loss           | 2.87e-07    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2951       |
# |    iterations           | 61         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 124928     |
# | train/                  |            |
# |    approx_kl            | 0.00380077 |
# |    clip_fraction        | 0.0375     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.27      |
# |    explained_variance   | -1.88      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000527   |
# |    n_updates            | 1580       |
# |    policy_gradient_loss | -0.00101   |
# |    value_loss           | 3.97e-07   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2951         |
# |    iterations           | 62           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0012690495 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.264       |
# |    explained_variance   | -1.65        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0106      |
# |    n_updates            | 1590         |
# |    policy_gradient_loss | -0.00051     |
# |    value_loss           | 3.13e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2951         |
# |    iterations           | 63           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 129024       |
# | train/                  |              |
# |    approx_kl            | 0.0029032798 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.23        |
# |    explained_variance   | -1.68        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00511     |
# |    n_updates            | 1600         |
# |    policy_gradient_loss | -0.00236     |
# |    value_loss           | 6.05e-07     |
# ...
# |    time_elapsed         | 54          |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.003831213 |
# |    clip_fraction        | 0.0332      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.229      |
# |    explained_variance   | -0.341      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00399     |
# |    n_updates            | 1750        |
# |    policy_gradient_loss | -0.00156    |
# |    value_loss           | 2.04e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2955         |
# |    iterations           | 79           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 161792       |
# | train/                  |              |
# |    approx_kl            | 0.0023413934 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.229       |
# |    explained_variance   | -2.81        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00742     |
# |    n_updates            | 1760         |
# |    policy_gradient_loss | 0.000661     |
# |    value_loss           | 1.38e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2956         |
# |    iterations           | 80           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0042859847 |
# |    clip_fraction        | 0.0399       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.255       |
# |    explained_variance   | -1.17        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00788     |
# |    n_updates            | 1770         |
# |    policy_gradient_loss | -0.000814    |
# |    value_loss           | 4.47e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2957        |
# |    iterations           | 81          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.001341336 |
# |    clip_fraction        | 0.0135      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.251      |
# |    explained_variance   | -0.675      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00534     |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -8.33e-05   |
# |    value_loss           | 2.85e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2958         |
# |    iterations           | 82           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0025806017 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.255       |
# |    explained_variance   | -1.59        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00328     |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | 0.000159     |
# |    value_loss           | 5.42e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2959         |
# |    iterations           | 83           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0006597892 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.231       |
# |    explained_variance   | -1.43        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00158      |
# |    n_updates            | 1800         |
# |    policy_gradient_loss | 0.00103      |
# |    value_loss           | 7.26e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2959         |
# |    iterations           | 84           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0030188716 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | -3.77        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00269      |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.000939    |
# |    value_loss           | 5.77e-08     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2960        |
# |    iterations           | 85          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.001923223 |
# |    clip_fraction        | 0.0186      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.233      |
# |    explained_variance   | -1.84       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00295    |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | 0.000239    |
# |    value_loss           | 7.74e-08    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2959          |
# |    iterations           | 86            |
# |    time_elapsed         | 59            |
# |    total_timesteps      | 176128        |
# | train/                  |               |
# |    approx_kl            | 0.00064720784 |
# |    clip_fraction        | 0.0309        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.249        |
# |    explained_variance   | -1.93         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00105       |
# |    n_updates            | 1830          |
# |    policy_gradient_loss | 0.000385      |
# |    value_loss           | 5.3e-08       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2958         |
# |    iterations           | 87           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0021730943 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.248       |
# |    explained_variance   | -1.32        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00531     |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | -0.000375    |
# |    value_loss           | 1.46e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2958        |
# |    iterations           | 88          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.001081176 |
# |    clip_fraction        | 0.0206      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.245      |
# |    explained_variance   | -4.06       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00287     |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.000407   |
# |    value_loss           | 2.45e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2958         |
# |    iterations           | 89           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0027225236 |
# |    clip_fraction        | 0.037        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.256       |
# |    explained_variance   | -0.475       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00139      |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.00282     |
# |    value_loss           | 1.05e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2957         |
# |    iterations           | 90           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0040294053 |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | -0.33        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00693      |
# |    n_updates            | 1870         |
# |    policy_gradient_loss | 0.000432     |
# |    value_loss           | 1.29e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2956         |
# |    iterations           | 91           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0060385186 |
# |    clip_fraction        | 0.0513       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.263       |
# |    explained_variance   | -0.527       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00305     |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 2.94e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2956        |
# |    iterations           | 92          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.008586707 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.281      |
# |    explained_variance   | -0.588      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000874   |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.00187    |
# |    value_loss           | 1.8e-05     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2957         |
# |    iterations           | 93           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0016538855 |
# |    clip_fraction        | 0.0231       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.253       |
# |    explained_variance   | -1.25        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0222      |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.00191     |
# |    value_loss           | 1.38e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2958         |
# |    iterations           | 94           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0025796026 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.269       |
# |    explained_variance   | -1.04        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -5.88e-06    |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | 0.000386     |
# |    value_loss           | 7.13e-08     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2959        |
# |    iterations           | 95          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.005097163 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.275      |
# |    explained_variance   | -0.712      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00407     |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.00295    |
# |    value_loss           | 9.05e-08    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2960        |
# |    iterations           | 96          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.002226268 |
# |    clip_fraction        | 0.0112      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.266      |
# |    explained_variance   | -0.846      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00711    |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.00021    |
# |    value_loss           | 7.09e-08    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2960         |
# |    iterations           | 97           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0011592245 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.274       |
# |    explained_variance   | -0.923       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -3.47e-05    |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | 0.000412     |
# |    value_loss           | 1.97e-07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2961          |
# |    iterations           | 98            |
# |    time_elapsed         | 67            |
# |    total_timesteps      | 200704        |
# | train/                  |               |
# |    approx_kl            | 0.00094496104 |
# |    clip_fraction        | 0.0136        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.263        |
# |    explained_variance   | -1.44         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00539      |
# |    n_updates            | 1950          |
# |    policy_gradient_loss | 0.000216      |
# |    value_loss           | 5.75e-07      |
# -------------------------------------------

# %% [markdown]
# ### Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
#On average is reward 500, std_dev = 0
# Out:
# (500.0, 0.0)

# %%
#Now the environment should be closed. Unless the window would stay opened till the end.
env.close()

# %% [markdown]
# ### Test the Model

# %%
episodes = 5
for episode in range(1, episodes+1):
    observation = env.reset() #Initial set of observations
    done = False 
    score = 0
    
    while not done:
        env.render() #View the graphical representation of environment
        action, _ = model.predict(observation)#Generate random actions
        # Two actions possible -> push left / right
        
        # env.observation_space
        # Observation_space -> Position, Velocity of Cart ; Pole Angle and Agular Velocity
        # These make 4 info, in other words Box(4)
        
        observation, reward, done, info= env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score:[500.]
# Episode:2 Score:[500.]
# Episode:3 Score:[500.]
# Episode:4 Score:[500.]
# Episode:5 Score:[500.]

# %% [markdown]
# ### Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_2')

# %%
training_log_path
# Out:
# 'Training/Logs/PPO_2'

# %%
#!tensorboard --logdir=.
# Out:
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.12.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C
# Der Kernel ist beim Ausführen von Code in der aktuellen Zelle oder einer vorherigen Zelle abgestürzt. Bitte überprüfen Sie den Code in der/den Zelle(n), um eine mögliche Fehlerursache zu identifizieren. Klicken Sie <a href='https://aka.ms/vscodeJupyterKernelCrash'>hier</a>, um weitere Informationen zu erhalten. Weitere Details finden Sie in Jupyter <a href='command:jupyter.viewOutput'>log</a>.
