# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# ### Load the Environment

# %%
environment = 'CartPole-v1'
env = gym.make(environment, render_mode="human")

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset() #Initial set of observations
    done = False 
    score = 0
    
    while not done:
        env.render() #View the graphical representation of environment
        action = env.action_space.sample()#Generate random actions
        # Two actions possible -> push left / right
        
        # env.observation_space
        # Observation_space -> Position, Velocity of Cart ; Pole Angle and Agular Velocity
        # These make 4 info, in other words Box(4)
        
        n_state, reward, done, info , extra_info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score:17.0
# Episode:2 Score:11.0
# Episode:3 Score:38.0
# Episode:4 Score:27.0
# Episode:5 Score:16.0

# %%
#Create/Make the directories
log_path = os.path.join('Training', 'Logs')
log_path
# Out:
# 'Training/Logs'

# %%
env = gym.make(environment)
#Wrapped the environment inside the DummyVecEnv
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# /Users/kyotun/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
#Timesteps depend on the complexity of the environment
model.learn(total_timesteps=200000)
# Out:
# Logging to Training/Logs/PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 7274 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4574        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008370907 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.00138     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.71        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 62.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4063        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012950969 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0953      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 34.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3856         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0071179345 |
# |    clip_fraction        | 0.0699       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.628       |
# |    explained_variance   | 0.174        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.8         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0159      |
# |    value_loss           | 54           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3783        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008604182 |
# |    clip_fraction        | 0.0927      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.604      |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 55.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3733        |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008953128 |
# |    clip_fraction        | 0.0801      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | 0.478       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 61          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3699        |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011374665 |
# |    clip_fraction        | 0.0961      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.2        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 47.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3678         |
# |    iterations           | 8            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0059065945 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.556       |
# |    explained_variance   | 0.784        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.3         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00377     |
# |    value_loss           | 37.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3652        |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006010591 |
# |    clip_fraction        | 0.0599      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.56       |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00715    |
# |    value_loss           | 24.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3634         |
# |    iterations           | 10           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0042152237 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.553       |
# |    explained_variance   | 0.784        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.29         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00594     |
# |    value_loss           | 38.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3607         |
# |    iterations           | 11           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0041695028 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.53        |
# |    explained_variance   | 0.527        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.4         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00499     |
# |    value_loss           | 63.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3589         |
# |    iterations           | 12           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0053890003 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.519       |
# |    explained_variance   | 0.825        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.9          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0058      |
# |    value_loss           | 15.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3574         |
# |    iterations           | 13           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0034070627 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.519       |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.484        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00495     |
# |    value_loss           | 7.15         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3561        |
# |    iterations           | 14          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005653782 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.522      |
# |    explained_variance   | 0.0498      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.239       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00346    |
# |    value_loss           | 2.73        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3547         |
# |    iterations           | 15           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0074592447 |
# |    clip_fraction        | 0.0629       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.52        |
# |    explained_variance   | 0.0863       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0549       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00511     |
# |    value_loss           | 1.87         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3538         |
# |    iterations           | 16           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0038827225 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.502       |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0831       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00373     |
# |    value_loss           | 1.12         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3529         |
# |    iterations           | 17           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0048980615 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.032        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0361       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 0.721        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3507       |
# |    iterations           | 18         |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00356808 |
# |    clip_fraction        | 0.0196     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.487     |
# |    explained_variance   | 0.0151     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0873     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00198   |
# |    value_loss           | 0.467      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3498         |
# |    iterations           | 19           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0022896896 |
# |    clip_fraction        | 0.0082       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.494       |
# |    explained_variance   | 0.00499      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.39         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 31.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3490        |
# |    iterations           | 20          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007984389 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0178      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00382    |
# |    value_loss           | 0.184       |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3470       |
# |    iterations           | 21         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.00587359 |
# |    clip_fraction        | 0.0456     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.5       |
# |    explained_variance   | -0.0145    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0153     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00245   |
# |    value_loss           | 0.11       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3458         |
# |    iterations           | 22           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0052619297 |
# |    clip_fraction        | 0.0479       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.492       |
# |    explained_variance   | 0.182        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0142       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00236     |
# |    value_loss           | 0.0703       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3441        |
# |    iterations           | 23          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006355528 |
# |    clip_fraction        | 0.0454      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.487      |
# |    explained_variance   | -0.0366     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00792    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0028     |
# |    value_loss           | 0.044       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3435         |
# |    iterations           | 24           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0025308798 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.48        |
# |    explained_variance   | -0.077       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.025       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 0.0272       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3424        |
# |    iterations           | 25          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004530878 |
# |    clip_fraction        | 0.0522      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.487      |
# |    explained_variance   | 0.0793      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0124      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 0.0179      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3425        |
# |    iterations           | 26          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.001488006 |
# |    clip_fraction        | 0.00327     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.493      |
# |    explained_variance   | 0.0033      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00377    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.000216   |
# |    value_loss           | 0.0116      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3427         |
# |    iterations           | 27           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0026308857 |
# |    clip_fraction        | 0.00898      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.483       |
# |    explained_variance   | -0.0713      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00122      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -4.18e-05    |
# |    value_loss           | 0.00723      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3433        |
# |    iterations           | 28          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.003969956 |
# |    clip_fraction        | 0.0297      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.485      |
# |    explained_variance   | -0.0534     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0105      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00159    |
# |    value_loss           | 0.00499     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3432        |
# |    iterations           | 29          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.001689402 |
# |    clip_fraction        | 0.00801     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.468      |
# |    explained_variance   | -0.0613     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0027      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 3.39e-05    |
# |    value_loss           | 0.00329     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3432        |
# |    iterations           | 30          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.005222963 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.464      |
# |    explained_variance   | -0.0256     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00991    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00322    |
# |    value_loss           | 0.00223     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3431         |
# |    iterations           | 31           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0035599796 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.463       |
# |    explained_variance   | 0.0149       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00327      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.000397    |
# |    value_loss           | 0.00161      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3421        |
# |    iterations           | 32          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.003957681 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.449      |
# |    explained_variance   | 0.00367     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0075     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 0.00108     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3405         |
# |    iterations           | 33           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0035343515 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.457       |
# |    explained_variance   | -0.0599      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00142      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | 1.22e-05     |
# |    value_loss           | 0.000687     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3398        |
# |    iterations           | 34          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004303078 |
# |    clip_fraction        | 0.0551      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.464      |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.011       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00413    |
# |    value_loss           | 0.000565    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3396         |
# |    iterations           | 35           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0040099006 |
# |    clip_fraction        | 0.023        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.454       |
# |    explained_variance   | -0.0949      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000721    |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00128     |
# |    value_loss           | 0.000355     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3397         |
# |    iterations           | 36           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0034964876 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.441       |
# |    explained_variance   | 0.0619       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0115      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00347     |
# |    value_loss           | 0.000266     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3403         |
# |    iterations           | 37           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0037762718 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.426       |
# |    explained_variance   | -0.00525     |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00622     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00393     |
# |    value_loss           | 0.000182     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3406        |
# |    iterations           | 38          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004735826 |
# |    clip_fraction        | 0.0647      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.433      |
# |    explained_variance   | -0.0871     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -3.53e-05   |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00168    |
# |    value_loss           | 0.000127    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3402        |
# |    iterations           | 39          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.002130061 |
# |    clip_fraction        | 0.0196      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.41       |
# |    explained_variance   | -0.0426     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0196     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00124    |
# |    value_loss           | 8.58e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3406         |
# |    iterations           | 40           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0029848416 |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.384       |
# |    explained_variance   | -0.0557      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00255      |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 6.37e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3411        |
# |    iterations           | 41          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.004038903 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.352      |
# |    explained_variance   | -0.0945     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00532    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00311    |
# |    value_loss           | 4.13e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3412         |
# |    iterations           | 42           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0028367853 |
# |    clip_fraction        | 0.0197       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.36        |
# |    explained_variance   | -0.0596      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00103     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000355    |
# |    value_loss           | 3.47e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3415         |
# |    iterations           | 43           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0011697651 |
# |    clip_fraction        | 0.00596      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.358       |
# |    explained_variance   | -0.151       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00278     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000271    |
# |    value_loss           | 2.37e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3421        |
# |    iterations           | 44          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.005082942 |
# |    clip_fraction        | 0.0368      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.332      |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0016      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 1.72e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3425         |
# |    iterations           | 45           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0040768282 |
# |    clip_fraction        | 0.0833       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.337       |
# |    explained_variance   | -0.315       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0215      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00508     |
# |    value_loss           | 1.19e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3427        |
# |    iterations           | 46          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.004292544 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.328      |
# |    explained_variance   | -0.4        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00713    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00207    |
# |    value_loss           | 9.31e-06    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3428          |
# |    iterations           | 47            |
# |    time_elapsed         | 28            |
# |    total_timesteps      | 96256         |
# | train/                  |               |
# |    approx_kl            | 0.00076131517 |
# |    clip_fraction        | 0.00498       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.328        |
# |    explained_variance   | -0.351        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0028        |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -2.9e-05      |
# |    value_loss           | 7.6e-06       |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3429        |
# |    iterations           | 48          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.003247931 |
# |    clip_fraction        | 0.0134      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.305      |
# |    explained_variance   | -0.755      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00533    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.000522   |
# |    value_loss           | 4.66e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3429         |
# |    iterations           | 49           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0017499321 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.289       |
# |    explained_variance   | -0.594       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00973      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 3.5e-06      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3429        |
# |    iterations           | 50          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.005553231 |
# |    clip_fraction        | 0.074       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.3        |
# |    explained_variance   | -0.354      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00622    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00113    |
# |    value_loss           | 4.45e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3429         |
# |    iterations           | 51           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0047896504 |
# |    clip_fraction        | 0.0358       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.316       |
# |    explained_variance   | -1.58        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0109       |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 3.37e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3430         |
# |    iterations           | 52           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0058494927 |
# |    clip_fraction        | 0.056        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.326       |
# |    explained_variance   | -1.11        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0217       |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 3.25e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3431         |
# |    iterations           | 53           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0025783237 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.301       |
# |    explained_variance   | -0.781       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00835      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 2.1e-06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3434         |
# |    iterations           | 54           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0011943048 |
# |    clip_fraction        | 0.00884      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.293       |
# |    explained_variance   | -1.64        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000414    |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00047     |
# |    value_loss           | 2.03e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3438         |
# |    iterations           | 55           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0017330411 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.275       |
# |    explained_variance   | -1.42        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00233     |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.000251    |
# |    value_loss           | 1.75e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3441         |
# |    iterations           | 56           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0005851778 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.282       |
# |    explained_variance   | -1.22        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00773      |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.000431    |
# |    value_loss           | 2.88e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3445        |
# |    iterations           | 57          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.001545761 |
# |    clip_fraction        | 0.0162      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.257      |
# |    explained_variance   | -1.55       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00499    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00168    |
# |    value_loss           | 1.84e-06    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3449          |
# |    iterations           | 58            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 118784        |
# | train/                  |               |
# |    approx_kl            | 0.00076860347 |
# |    clip_fraction        | 0.0172        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.253        |
# |    explained_variance   | -2.33         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00323      |
# |    n_updates            | 570           |
# |    policy_gradient_loss | 0.00061       |
# |    value_loss           | 5.8e-06       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3452         |
# |    iterations           | 59           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0015403575 |
# |    clip_fraction        | 0.0141       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.248       |
# |    explained_variance   | -2.62        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00126      |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.000491    |
# |    value_loss           | 1.72e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3455        |
# |    iterations           | 60          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.004175599 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.271      |
# |    explained_variance   | -3.45       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00796     |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.000467   |
# |    value_loss           | 1.63e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3458         |
# |    iterations           | 61           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0009988443 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.258       |
# |    explained_variance   | -1.7         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0032      |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 2.73e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3461          |
# |    iterations           | 62            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 126976        |
# | train/                  |               |
# |    approx_kl            | 0.00093980134 |
# |    clip_fraction        | 0.0131        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.259        |
# |    explained_variance   | -1.38         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00294       |
# |    n_updates            | 610           |
# |    policy_gradient_loss | -0.000193     |
# |    value_loss           | 8.5e-07       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3464         |
# |    iterations           | 63           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 129024       |
# | train/                  |              |
# |    approx_kl            | 0.0021528327 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.233       |
# |    explained_variance   | -2.59        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00141      |
# |    n_updates            | 620          |
# |    policy_gradient_loss | 0.000598     |
# |    value_loss           | 7.25e-07     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3464       |
# |    iterations           | 64         |
# |    time_elapsed         | 37         |
# ...
# |    time_elapsed         | 46           |
# |    total_timesteps      | 159744       |
# | train/                  |              |
# |    approx_kl            | 0.0019285361 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.262       |
# |    explained_variance   | -1.55        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00962      |
# |    n_updates            | 770          |
# |    policy_gradient_loss | -0.000563    |
# |    value_loss           | 1.22e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3460         |
# |    iterations           | 79           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 161792       |
# | train/                  |              |
# |    approx_kl            | 0.0022365155 |
# |    clip_fraction        | 0.0158       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.234       |
# |    explained_variance   | -2.18        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000249     |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 2.71e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3462        |
# |    iterations           | 80          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.004004439 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.27       |
# |    explained_variance   | -2.89       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00646     |
# |    n_updates            | 790         |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 3.26e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3464         |
# |    iterations           | 81           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0016821253 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.251       |
# |    explained_variance   | -2.17        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00238      |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.000267    |
# |    value_loss           | 5.01e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3464         |
# |    iterations           | 82           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0016693322 |
# |    clip_fraction        | 0.0085       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.262       |
# |    explained_variance   | -5.7         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00289      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | 0.00044      |
# |    value_loss           | 4.33e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3466         |
# |    iterations           | 83           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 169984       |
# | train/                  |              |
# |    approx_kl            | 0.0026165638 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | -0.974       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0085      |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.00063     |
# |    value_loss           | 6.71e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3468        |
# |    iterations           | 84          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.004102409 |
# |    clip_fraction        | 0.0391      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.249      |
# |    explained_variance   | -1.32       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00627    |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0018     |
# |    value_loss           | 3.25e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3470         |
# |    iterations           | 85           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0074084876 |
# |    clip_fraction        | 0.0507       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.28        |
# |    explained_variance   | -3.07        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00849     |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.00113     |
# |    value_loss           | 2.3e-07      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3471         |
# |    iterations           | 86           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0044260356 |
# |    clip_fraction        | 0.0505       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.286       |
# |    explained_variance   | -6.79        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00203     |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 2.5e-07      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3471        |
# |    iterations           | 87          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.001519031 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.27       |
# |    explained_variance   | -2.98       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00327     |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00141    |
# |    value_loss           | 1.99e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3471         |
# |    iterations           | 88           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0010925833 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.267       |
# |    explained_variance   | -2.85        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0125       |
# |    n_updates            | 870          |
# |    policy_gradient_loss | -0.000409    |
# |    value_loss           | 1.91e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3471         |
# |    iterations           | 89           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0019384527 |
# |    clip_fraction        | 0.027        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.271       |
# |    explained_variance   | -6.32        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00399      |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 1.42e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3471         |
# |    iterations           | 90           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0039119665 |
# |    clip_fraction        | 0.0294       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.264       |
# |    explained_variance   | -0.805       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00469     |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 2.46e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3471         |
# |    iterations           | 91           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0023510605 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.255       |
# |    explained_variance   | -1.01        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.011        |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 3.69e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3471         |
# |    iterations           | 92           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0007494952 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | -2.25        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00632      |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 8.24e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3472         |
# |    iterations           | 93           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0006534533 |
# |    clip_fraction        | 0.00352      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.244       |
# |    explained_variance   | -0.684       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000849    |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -3.34e-05    |
# |    value_loss           | 2.11e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3472         |
# |    iterations           | 94           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0025299916 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | -1.32        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0099       |
# |    n_updates            | 930          |
# |    policy_gradient_loss | 0.000541     |
# |    value_loss           | 1.13e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3474         |
# |    iterations           | 95           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0018387354 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.245       |
# |    explained_variance   | -1.08        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00846     |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 1.79e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3475         |
# |    iterations           | 96           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0018819836 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.256       |
# |    explained_variance   | -1.48        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00467      |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 2.12e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3477        |
# |    iterations           | 97          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.011869964 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.278      |
# |    explained_variance   | -1.61       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00792     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00115    |
# |    value_loss           | 2.98e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3479        |
# |    iterations           | 98          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.001140269 |
# |    clip_fraction        | 0.0122      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.269      |
# |    explained_variance   | -0.933      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00369     |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.000672   |
# |    value_loss           | 1.33e-06    |
# -----------------------------------------

# %% [markdown]
# ### Save and Reload Model

# %%
PPO_Path = os.path.join('Training', 'Saved Models', 'PPO_Model_Cartpole')

# %%
model.save(PPO_Path)

# %%
#Delete the model and reload it
del model

# %%
model = PPO.load(PPO_Path, env=env)

# %%
model.learn(total_timesteps=200000)
# Out:
# Logging to Training/Logs/PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 7383 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4876         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0012849824 |
# |    clip_fraction        | 0.0062       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.25        |
# |    explained_variance   | -1.8         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00113      |
# |    n_updates            | 990          |
# |    policy_gradient_loss | 0.000553     |
# |    value_loss           | 2.9e-06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4359         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0013901487 |
# |    clip_fraction        | 0.0194       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | -1.77        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0021      |
# |    n_updates            | 1000         |
# |    policy_gradient_loss | -0.000175    |
# |    value_loss           | 3.84e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4149         |
# |    iterations           | 4            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0012831707 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | -2.27        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00253     |
# |    n_updates            | 1010         |
# |    policy_gradient_loss | -0.000259    |
# |    value_loss           | 1.43e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4029         |
# |    iterations           | 5            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0031405417 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.251       |
# |    explained_variance   | -1.96        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00211     |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | 0.00042      |
# |    value_loss           | 6.53e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3934         |
# |    iterations           | 6            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0025084328 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | -0.985       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00222     |
# |    n_updates            | 1030         |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 1.43e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3859        |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.001434281 |
# |    clip_fraction        | 0.00693     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.243      |
# |    explained_variance   | -4.42       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00157     |
# |    n_updates            | 1040        |
# |    policy_gradient_loss | 3.29e-05    |
# |    value_loss           | 1.68e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3797         |
# |    iterations           | 8            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0014799495 |
# |    clip_fraction        | 0.00903      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.235       |
# |    explained_variance   | -4.44        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000106     |
# |    n_updates            | 1050         |
# |    policy_gradient_loss | 0.000463     |
# |    value_loss           | 2.54e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3751         |
# |    iterations           | 9            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0024501188 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.259       |
# |    explained_variance   | -3.64        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00327      |
# |    n_updates            | 1060         |
# |    policy_gradient_loss | 0.000353     |
# |    value_loss           | 2.06e-05     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3723       |
# |    iterations           | 10         |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.00245015 |
# |    clip_fraction        | 0.0206     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.265     |
# |    explained_variance   | -1.66      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00167    |
# |    n_updates            | 1070       |
# |    policy_gradient_loss | -0.000573  |
# |    value_loss           | 1.24e-06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3700        |
# |    iterations           | 11          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.004518858 |
# |    clip_fraction        | 0.0329      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.27       |
# |    explained_variance   | -1.96       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00426    |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | -0.000138   |
# |    value_loss           | 1.85e-07    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3683          |
# |    iterations           | 12            |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 24576         |
# | train/                  |               |
# |    approx_kl            | 0.00033297171 |
# |    clip_fraction        | 0.0214        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.26         |
# |    explained_variance   | -1.59         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00154      |
# |    n_updates            | 1090          |
# |    policy_gradient_loss | 0.000377      |
# |    value_loss           | 2.3e-07       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3663         |
# |    iterations           | 13           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0020918956 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.248       |
# |    explained_variance   | -2.15        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00354      |
# |    n_updates            | 1100         |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 1.67e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3642         |
# |    iterations           | 14           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0023390502 |
# |    clip_fraction        | 0.00762      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.258       |
# |    explained_variance   | -3.86        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00568     |
# |    n_updates            | 1110         |
# |    policy_gradient_loss | -0.000157    |
# |    value_loss           | 3.75e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3643         |
# |    iterations           | 15           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0005618519 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.258       |
# |    explained_variance   | -3.07        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000508     |
# |    n_updates            | 1120         |
# |    policy_gradient_loss | 3.21e-05     |
# |    value_loss           | 1.33e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3632         |
# |    iterations           | 16           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0028885612 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.242       |
# |    explained_variance   | -5.37        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00322     |
# |    n_updates            | 1130         |
# |    policy_gradient_loss | -0.000437    |
# |    value_loss           | 1.1e-05      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3620         |
# |    iterations           | 17           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0006286578 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | -1.8         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00227      |
# |    n_updates            | 1140         |
# |    policy_gradient_loss | 9.09e-05     |
# |    value_loss           | 2.05e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3621         |
# |    iterations           | 18           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0030754185 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.258       |
# |    explained_variance   | -1.68        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0125      |
# |    n_updates            | 1150         |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 1.07e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3618         |
# |    iterations           | 19           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0025787633 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.266       |
# |    explained_variance   | -3.85        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00374      |
# |    n_updates            | 1160         |
# |    policy_gradient_loss | -0.000815    |
# |    value_loss           | 1.83e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3619         |
# |    iterations           | 20           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0027991105 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.259       |
# |    explained_variance   | -2.62        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00169      |
# |    n_updates            | 1170         |
# |    policy_gradient_loss | -0.000413    |
# |    value_loss           | 7.03e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3609        |
# |    iterations           | 21          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.003373343 |
# |    clip_fraction        | 0.0189      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.27       |
# |    explained_variance   | -3.56       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.17e-05    |
# |    n_updates            | 1180        |
# |    policy_gradient_loss | -0.000696   |
# |    value_loss           | 2.11e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3611         |
# |    iterations           | 22           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0017042992 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.263       |
# |    explained_variance   | -2.7         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0131       |
# |    n_updates            | 1190         |
# |    policy_gradient_loss | 0.000312     |
# |    value_loss           | 3.45e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3607         |
# |    iterations           | 23           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0043398617 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.266       |
# |    explained_variance   | -4.82        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0101       |
# |    n_updates            | 1200         |
# |    policy_gradient_loss | -0.000204    |
# |    value_loss           | 4.04e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3602         |
# |    iterations           | 24           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0023322622 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.248       |
# |    explained_variance   | -3.26        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000457     |
# |    n_updates            | 1210         |
# |    policy_gradient_loss | 0.000393     |
# |    value_loss           | 1.29e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3597         |
# |    iterations           | 25           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0006622743 |
# |    clip_fraction        | 0.024        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.274       |
# |    explained_variance   | -8.2         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00339      |
# |    n_updates            | 1220         |
# |    policy_gradient_loss | 0.000697     |
# |    value_loss           | 4.64e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3593         |
# |    iterations           | 26           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0012831322 |
# |    clip_fraction        | 0.0213       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.268       |
# |    explained_variance   | -8.7         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0141       |
# |    n_updates            | 1230         |
# |    policy_gradient_loss | 0.000339     |
# |    value_loss           | 6.79e-07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3589          |
# |    iterations           | 27            |
# |    time_elapsed         | 15            |
# |    total_timesteps      | 55296         |
# | train/                  |               |
# |    approx_kl            | 0.00043699145 |
# |    clip_fraction        | 0.0105        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.264        |
# |    explained_variance   | -4.22         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000207      |
# |    n_updates            | 1240          |
# |    policy_gradient_loss | 0.000351      |
# |    value_loss           | 2.13e-07      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3585        |
# |    iterations           | 28          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.001214057 |
# |    clip_fraction        | 0.0125      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.252      |
# |    explained_variance   | -5.09       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0104     |
# |    n_updates            | 1250        |
# |    policy_gradient_loss | -0.000693   |
# |    value_loss           | 1.19e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3582         |
# |    iterations           | 29           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0006938356 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.241       |
# |    explained_variance   | -2           |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00859     |
# |    n_updates            | 1260         |
# |    policy_gradient_loss | -0.000713    |
# |    value_loss           | 8.8e-06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3579         |
# |    iterations           | 30           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0012489433 |
# |    clip_fraction        | 0.012        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.261       |
# |    explained_variance   | -2.12        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00768     |
# |    n_updates            | 1270         |
# |    policy_gradient_loss | 0.000852     |
# |    value_loss           | 3.31e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3576         |
# |    iterations           | 31           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0025503435 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | -0.474       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.86e-05     |
# |    n_updates            | 1280         |
# |    policy_gradient_loss | -0.00117     |
# |    value_loss           | 1.27e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3578         |
# |    iterations           | 32           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0019473347 |
# |    clip_fraction        | 0.0188       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.241       |
# |    explained_variance   | -0.693       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00292      |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | 0.000551     |
# |    value_loss           | 1.9e-07      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3577         |
# |    iterations           | 33           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0016069605 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.252       |
# |    explained_variance   | -1.22        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000894     |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | 0.000859     |
# |    value_loss           | 4.17e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3579         |
# |    iterations           | 34           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0014454722 |
# |    clip_fraction        | 0.0337       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | -1.49        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00383     |
# |    n_updates            | 1310         |
# |    policy_gradient_loss | 7.75e-05     |
# |    value_loss           | 4.26e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3577         |
# |    iterations           | 35           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0020806028 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.268       |
# |    explained_variance   | -1.31        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00597      |
# |    n_updates            | 1320         |
# |    policy_gradient_loss | -0.000597    |
# |    value_loss           | 3.96e-06     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3569          |
# |    iterations           | 36            |
# |    time_elapsed         | 20            |
# |    total_timesteps      | 73728         |
# | train/                  |               |
# |    approx_kl            | 0.00037949832 |
# |    clip_fraction        | 0.00996       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.247        |
# |    explained_variance   | -6.95         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.000765     |
# |    n_updates            | 1330          |
# |    policy_gradient_loss | -6.46e-05     |
# |    value_loss           | 5.56e-07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3568         |
# |    iterations           | 37           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0009683295 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.26        |
# |    explained_variance   | -6.31        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000695    |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | 0.000384     |
# |    value_loss           | 3.82e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3569         |
# |    iterations           | 38           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0027556657 |
# |    clip_fraction        | 0.0436       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.259       |
# |    explained_variance   | -9.24        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0169       |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | -0.000664    |
# |    value_loss           | 5.55e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3570         |
# |    iterations           | 39           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0018661905 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.233       |
# |    explained_variance   | -2.44        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00232     |
# |    n_updates            | 1360         |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 7.34e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3565         |
# |    iterations           | 40           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0009405749 |
# |    clip_fraction        | 0.0154       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.229       |
# |    explained_variance   | -4.72        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00988     |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.00059     |
# |    value_loss           | 3.36e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3562         |
# |    iterations           | 41           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0015120743 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | -7.62        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00704      |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.000185    |
# |    value_loss           | 6.74e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3560         |
# |    iterations           | 42           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0037442269 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.245       |
# |    explained_variance   | -2.68        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00124     |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | 0.000355     |
# |    value_loss           | 7.02e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3553        |
# |    iterations           | 43          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004005879 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.228      |
# |    explained_variance   | -1.36       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00674     |
# |    n_updates            | 1400        |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 8.34e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3554         |
# |    iterations           | 44           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0011048212 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.248       |
# |    explained_variance   | -1.64        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00335     |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | 0.000499     |
# |    value_loss           | 8.62e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3554         |
# |    iterations           | 45           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0011204584 |
# |    clip_fraction        | 0.00703      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.236       |
# |    explained_variance   | -0.959       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00165     |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | 0.000647     |
# |    value_loss           | 9.95e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3549         |
# |    iterations           | 46           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0013762729 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | -4.22        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000471     |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | -0.00018     |
# |    value_loss           | 4.9e-07      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3546         |
# |    iterations           | 47           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0012072064 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.254       |
# |    explained_variance   | -4.98        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00413     |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.000937    |
# |    value_loss           | 9.03e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3544         |
# |    iterations           | 48           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0025244472 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.234       |
# |    explained_variance   | -6.5         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0107      |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | -0.000228    |
# |    value_loss           | 2.27e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3545         |
# |    iterations           | 49           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0016724266 |
# |    clip_fraction        | 0.00864      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.229       |
# |    explained_variance   | -1.97        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00691      |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | 3.68e-05     |
# |    value_loss           | 6.87e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3544         |
# |    iterations           | 50           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0031478833 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.255       |
# |    explained_variance   | -3.87        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -6.7e-05     |
# |    n_updates            | 1470         |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 4.51e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3546         |
# |    iterations           | 51           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0018442441 |
# |    clip_fraction        | 0.03         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.228       |
# |    explained_variance   | -2.18        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00174      |
# |    n_updates            | 1480         |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 1.83e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3547        |
# |    iterations           | 52          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.002446944 |
# |    clip_fraction        | 0.0251      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.216      |
# |    explained_variance   | -2.95       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00418     |
# |    n_updates            | 1490        |
# |    policy_gradient_loss | 0.00128     |
# |    value_loss           | 5.85e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3549         |
# |    iterations           | 53           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0012229542 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.225       |
# |    explained_variance   | -3.05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00143      |
# |    n_updates            | 1500         |
# |    policy_gradient_loss | 0.000323     |
# |    value_loss           | 1.33e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3549        |
# |    iterations           | 54          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.004178372 |
# |    clip_fraction        | 0.0418      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.226      |
# |    explained_variance   | -1.81       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00125     |
# |    n_updates            | 1510        |
# |    policy_gradient_loss | -0.00219    |
# |    value_loss           | 8.93e-08    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3549       |
# |    iterations           | 55         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 112640     |
# | train/                  |            |
# |    approx_kl            | 0.00112085 |
# |    clip_fraction        | 0.0124     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.229     |
# |    explained_variance   | -2.65      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0177     |
# |    n_updates            | 1520       |
# |    policy_gradient_loss | 0.000421   |
# |    value_loss           | 1.58e-07   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3551         |
# |    iterations           | 56           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0012212265 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.24        |
# |    explained_variance   | -1.78        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00193      |
# |    n_updates            | 1530         |
# |    policy_gradient_loss | 0.000145     |
# |    value_loss           | 4.29e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3551         |
# |    iterations           | 57           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0005556384 |
# |    clip_fraction        | 0.00825      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.231       |
# |    explained_variance   | -3.29        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00334     |
# |    n_updates            | 1540         |
# |    policy_gradient_loss | 0.00068      |
# |    value_loss           | 6.61e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3550         |
# |    iterations           | 58           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0043052044 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.242       |
# |    explained_variance   | -2.64        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00873      |
# |    n_updates            | 1550         |
# |    policy_gradient_loss | 0.000233     |
# |    value_loss           | 5.78e-08     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3548       |
# |    iterations           | 59         |
# |    time_elapsed         | 34         |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.00235022 |
# |    clip_fraction        | 0.0508     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.249     |
# |    explained_variance   | -3.37      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00734    |
# |    n_updates            | 1560       |
# |    policy_gradient_loss | -0.00055   |
# |    value_loss           | 8.23e-08   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3547         |
# |    iterations           | 60           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0015490438 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.261       |
# |    explained_variance   | -3.18        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00144     |
# |    n_updates            | 1570         |
# |    policy_gradient_loss | 0.000447     |
# |    value_loss           | 7.54e-08     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3547        |
# |    iterations           | 61          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.002995967 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.262      |
# |    explained_variance   | -2.73       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00443    |
# |    n_updates            | 1580        |
# |    policy_gradient_loss | -0.00137    |
# |    value_loss           | 3e-07       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3546         |
# |    iterations           | 62           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 126976       |
# | train/                  |              |
# |    approx_kl            | 0.0024256224 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.256       |
# |    explained_variance   | -5.58        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00196     |
# |    n_updates            | 1590         |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 1.83e-07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3545          |
# |    iterations           | 63            |
# |    time_elapsed         | 36            |
# |    total_timesteps      | 129024        |
# | train/                  |               |
# |    approx_kl            | 0.00084711466 |
# |    clip_fraction        | 0.0186        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.264        |
# |    explained_variance   | -4.52         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00782      |
# |    n_updates            | 1600          |
# |    policy_gradient_loss | 0.000249      |
# ...
# | train/                  |              |
# |    approx_kl            | 0.0010182539 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.236       |
# |    explained_variance   | -1.6         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00337      |
# |    n_updates            | 1750         |
# |    policy_gradient_loss | -0.000101    |
# |    value_loss           | 1.6e-06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3537         |
# |    iterations           | 79           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 161792       |
# | train/                  |              |
# |    approx_kl            | 0.0017391951 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.218       |
# |    explained_variance   | -1.27        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00263      |
# |    n_updates            | 1760         |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 1.04e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3535        |
# |    iterations           | 80          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.004466087 |
# |    clip_fraction        | 0.0322      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.251      |
# |    explained_variance   | -3.32       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00869    |
# |    n_updates            | 1770        |
# |    policy_gradient_loss | -0.00115    |
# |    value_loss           | 1.84e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3531         |
# |    iterations           | 81           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0019035813 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.234       |
# |    explained_variance   | -2.11        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00758      |
# |    n_updates            | 1780         |
# |    policy_gradient_loss | -0.00072     |
# |    value_loss           | 1.09e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3530         |
# |    iterations           | 82           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0037139999 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.23        |
# |    explained_variance   | -1.85        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -5.48e-05    |
# |    n_updates            | 1790         |
# |    policy_gradient_loss | 5.76e-05     |
# |    value_loss           | 8.4e-08      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3528        |
# |    iterations           | 83          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.002083739 |
# |    clip_fraction        | 0.0177      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.223      |
# |    explained_variance   | -0.921      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00647     |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.000735   |
# |    value_loss           | 1.2e-07     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3528         |
# |    iterations           | 84           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0031795695 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.236       |
# |    explained_variance   | -1.41        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00936     |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 1.49e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3529         |
# |    iterations           | 85           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0015469195 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | -2           |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00366     |
# |    n_updates            | 1820         |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 6.69e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3530         |
# |    iterations           | 86           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0014841382 |
# |    clip_fraction        | 0.00952      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | -1.24        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00712     |
# |    n_updates            | 1830         |
# |    policy_gradient_loss | -0.000984    |
# |    value_loss           | 3.56e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3530         |
# |    iterations           | 87           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0018510666 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.233       |
# |    explained_variance   | -2.49        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0106       |
# |    n_updates            | 1840         |
# |    policy_gradient_loss | 0.000532     |
# |    value_loss           | 1.64e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3529         |
# |    iterations           | 88           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0011991172 |
# |    clip_fraction        | 0.00986      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.224       |
# |    explained_variance   | -1.37        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00445      |
# |    n_updates            | 1850         |
# |    policy_gradient_loss | -0.000654    |
# |    value_loss           | 5.72e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3531         |
# |    iterations           | 89           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0009377868 |
# |    clip_fraction        | 0.0115       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.205       |
# |    explained_variance   | -0.396       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00255     |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 8.49e-08     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3532        |
# |    iterations           | 90          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.004283739 |
# |    clip_fraction        | 0.0433      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.233      |
# |    explained_variance   | -0.696      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00225    |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.00113    |
# |    value_loss           | 9.21e-08    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3534         |
# |    iterations           | 91           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0042582587 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.26        |
# |    explained_variance   | -1.39        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00653     |
# |    n_updates            | 1880         |
# |    policy_gradient_loss | -0.000713    |
# |    value_loss           | 2.74e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3534         |
# |    iterations           | 92           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0018132969 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.248       |
# |    explained_variance   | -2.34        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00401      |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | 0.000684     |
# |    value_loss           | 1.43e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3533         |
# |    iterations           | 93           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0028948204 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.236       |
# |    explained_variance   | -1.05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00151      |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.00245     |
# |    value_loss           | 4.8e-06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3533         |
# |    iterations           | 94           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0012664611 |
# |    clip_fraction        | 0.0083       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | -2.05        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00153     |
# |    n_updates            | 1910         |
# |    policy_gradient_loss | 0.000171     |
# |    value_loss           | 3.01e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3533         |
# |    iterations           | 95           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0039277626 |
# |    clip_fraction        | 0.034        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.235       |
# |    explained_variance   | -0.669       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00926     |
# |    n_updates            | 1920         |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 2.1e-06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3532         |
# |    iterations           | 96           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0018872076 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.245       |
# |    explained_variance   | -1.3         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00336      |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 5.32e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3531         |
# |    iterations           | 97           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0029719633 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.254       |
# |    explained_variance   | -0.868       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00496      |
# |    n_updates            | 1940         |
# |    policy_gradient_loss | -0.00142     |
# |    value_loss           | 4.78e-07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3531          |
# |    iterations           | 98            |
# |    time_elapsed         | 56            |
# |    total_timesteps      | 200704        |
# | train/                  |               |
# |    approx_kl            | 0.00030429807 |
# |    clip_fraction        | 0.0157        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.23         |
# |    explained_variance   | -1.9          |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00454      |
# |    n_updates            | 1950          |
# |    policy_gradient_loss | -2.54e-06     |
# |    value_loss           | 7.94e-06      |
# -------------------------------------------

# %% [markdown]
# ### Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
#On average is reward 500, std_dev = 0
# Out:
# /Users/kyotun/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /Users/kyotun/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:234: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# (500.0, 0.0)

# %%
#Now the environment should be closed. Unless the window would stay opened till the end.
env.close()

# %% [markdown]
# ### Test the Model

# %%
episodes = 5
for episode in range(1, episodes+1):
    observation = env.reset() #Initial set of observations
    done = False 
    score = 0
    
    while not done:
        env.render() #View the graphical representation of environment
        action, _ = model.predict(observation)#Generate random actions
        # Two actions possible -> push left / right
        
        # env.observation_space
        # Observation_space -> Position, Velocity of Cart ; Pole Angle and Agular Velocity
        # These make 4 info, in other words Box(4)
        
        observation, reward, done, info= env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score:[500.]
# Episode:2 Score:[500.]
# Episode:3 Score:[500.]
# Episode:4 Score:[500.]
# Episode:5 Score:[500.]

# %% [markdown]
# ### Viewing Logs in Tensorboard

# %%
training_log_path = os.path.join(log_path, 'PPO_2')

# %%
training_log_path
# Out:
# 'Training/Logs/PPO_2'

# %%
#!tensorboard --logdir=.

# %% [markdown]
# ### Adding a callback to the training State

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved Models')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=500, verbose=1)
eval_callback = EvalCallback(env,
                             callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
model = PPO('MlpPolicy', environment, tensorboard_log=log_path)
#Mlp -> Multi layer perceptron policy

# %%
model.learn(total_timesteps=100000, callback=eval_callback)
# Out:
# /Users/kyotun/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=380.80 +/- 150.47
# Episode length: 380.80 +/- 150.47
# New best mean reward!
# Eval num_timesteps=20000, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# New best mean reward!
# Stopping training because the mean reward 500.00  is above the threshold 500

# %% [markdown]
# ### Changing Policies

# %%
#Changing the architechture
net_arch = [dict(pi=[128,128,128,128], vf=[128,128,128,128])]

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=100000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_8
# -----------------------------
# | time/              |      |
# |    fps             | 5666 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3080        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015560007 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | -0.00273    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0245     |
# |    value_loss           | 17.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2658        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.016616862 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.645      |
# |    explained_variance   | 0.423       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0322     |
# |    value_loss           | 27.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2471        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013540899 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.318       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 44.5        |
# -----------------------------------------
# Eval num_timesteps=9168, episode_reward=438.80 +/- 76.48
# Episode length: 438.80 +/- 76.48
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 439         |
# |    mean_reward          | 439         |
# | time/                   |             |
# |    total_timesteps      | 9168        |
# | train/                  |             |
# |    approx_kl            | 0.015094386 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.561      |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.33        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 30.7        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 2264  |
# |    iterations      | 5     |
# |    time_elapsed    | 4     |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2235        |
# |    iterations           | 6           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010502488 |
# |    clip_fraction        | 0.0783      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.542      |
# |    explained_variance   | 0.729       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.92        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00685    |
# |    value_loss           | 23.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2220         |
# |    iterations           | 7            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0037383493 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.548       |
# |    explained_variance   | 0.92         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.943        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00265     |
# |    value_loss           | 10.3         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2211         |
# |    iterations           | 8            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0049767187 |
# |    clip_fraction        | 0.0901       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.5         |
# |    explained_variance   | 0.668        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.81         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00738     |
# |    value_loss           | 20.2         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2204       |
# |    iterations           | 9          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00584964 |
# |    clip_fraction        | 0.0722     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.492     |
# |    explained_variance   | 0.911      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.634      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00294   |
# |    value_loss           | 7.15       |
# ----------------------------------------
# Eval num_timesteps=19168, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 500         |
# |    mean_reward          | 500         |
# | time/                   |             |
# |    total_timesteps      | 19168       |
# | train/                  |             |
# |    approx_kl            | 0.012665182 |
# |    clip_fraction        | 0.0978      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.481      |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.414       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00436    |
# |    value_loss           | 3.81        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 2134  |
# |    iterations      | 10    |
# |    time_elapsed    | 9     |
# |    total_timesteps | 20480 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2136        |
# |    iterations           | 11          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.008492803 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.435      |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0335      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00744    |
# |    value_loss           | 1.41        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2141         |
# |    iterations           | 12           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0062858714 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.431       |
# |    explained_variance   | 0.77         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.281        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00304     |
# |    value_loss           | 1.26         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2143        |
# |    iterations           | 13          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006583375 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.421      |
# |    explained_variance   | 0.455       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.145       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00641    |
# |    value_loss           | 0.866       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2146         |
# |    iterations           | 14           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0053953435 |
# |    clip_fraction        | 0.0701       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.43        |
# |    explained_variance   | 0.0399       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0923       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000821    |
# |    value_loss           | 0.56         |
# ------------------------------------------
# Eval num_timesteps=29168, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 500         |
# |    mean_reward          | 500         |
# | time/                   |             |
# |    total_timesteps      | 29168       |
# | train/                  |             |
# |    approx_kl            | 0.005293167 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.457      |
# |    explained_variance   | 0.0274      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0398      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.000922    |
# |    value_loss           | 0.399       |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 2107  |
# |    iterations      | 15    |
# |    time_elapsed    | 14    |
# |    total_timesteps | 30720 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2112         |
# |    iterations           | 16           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0075016334 |
# |    clip_fraction        | 0.0692       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.466       |
# |    explained_variance   | -0.0128      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0438       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 0.239        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2116        |
# |    iterations           | 17          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007645596 |
# |    clip_fraction        | 0.0442      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | -0.019      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0104      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.00183     |
# |    value_loss           | 0.184       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2121         |
# |    iterations           | 18           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0026969723 |
# |    clip_fraction        | 0.0407       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.486       |
# |    explained_variance   | -0.00601     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0151       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 0.000129     |
# |    value_loss           | 0.104        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2124        |
# |    iterations           | 19          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005187857 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.484      |
# |    explained_variance   | -0.134      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0195      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00079    |
# |    value_loss           | 0.0688      |
# -----------------------------------------
# Eval num_timesteps=39168, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 500          |
# |    mean_reward          | 500          |
# | time/                   |              |
# |    total_timesteps      | 39168        |
# | train/                  |              |
# |    approx_kl            | 0.0036653066 |
# |    clip_fraction        | 0.0393       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.515       |
# |    explained_variance   | -0.00674     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00935      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.000312     |
# |    value_loss           | 0.0474       |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 2095  |
# |    iterations      | 20    |
# |    time_elapsed    | 19    |
# |    total_timesteps | 40960 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2100         |
# |    iterations           | 21           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0024112032 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.515       |
# |    explained_variance   | -0.0274      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00128      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.000583     |
# |    value_loss           | 0.0314       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2104        |
# |    iterations           | 22          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008698614 |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.545      |
# |    explained_variance   | -0.00658    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.012       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00227    |
# |    value_loss           | 0.0191      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2107        |
# |    iterations           | 23          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008547373 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.549      |
# |    explained_variance   | 0.148       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.074       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.000639   |
# |    value_loss           | 3.21        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2110        |
# |    iterations           | 24          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.001354232 |
# |    clip_fraction        | 0.00146     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.89        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000977   |
# |    value_loss           | 19.7        |
# -----------------------------------------
# Eval num_timesteps=49168, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 500          |
# |    mean_reward          | 500          |
# | time/                   |              |
# |    total_timesteps      | 49168        |
# | train/                  |              |
# |    approx_kl            | 0.0037860295 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.507       |
# |    explained_variance   | 0.109        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.8         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00587     |
# |    value_loss           | 55.7         |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 2088  |
# |    iterations      | 25    |
# |    time_elapsed    | 24    |
# |    total_timesteps | 51200 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2091        |
# |    iterations           | 26          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.006835605 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.507      |
# |    explained_variance   | 0.33        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.86        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00647    |
# |    value_loss           | 8.05        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2094        |
# |    iterations           | 27          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.004313474 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.307       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00496    |
# |    value_loss           | 1.13        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2096         |
# |    iterations           | 28           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0078664655 |
# |    clip_fraction        | 0.085        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.498       |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.474        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00684     |
# |    value_loss           | 1.51         |
# ------------------------------------------
# Eval num_timesteps=59168, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 500          |
# |    mean_reward          | 500          |
# | time/                   |              |
# |    total_timesteps      | 59168        |
# | train/                  |              |
# |    approx_kl            | 0.0073814252 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.473       |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.348        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0141      |
# |    value_loss           | 0.574        |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 2077  |
# |    iterations      | 29    |
# |    time_elapsed    | 28    |
# |    total_timesteps | 59392 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2080        |
# |    iterations           | 30          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.014971629 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.461      |
# |    explained_variance   | 0.878       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.122       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 0.238       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2083        |
# |    iterations           | 31          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.026065655 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.437      |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0101     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0164     |
# |    value_loss           | 0.00247     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2085        |
# |    iterations           | 32          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.013190577 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.46       |
# |    explained_variance   | -0.214      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0026      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00721    |
# |    value_loss           | 0.00303     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2089        |
# |    iterations           | 33          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011257146 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.455      |
# |    explained_variance   | -0.156      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0102      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00153    |
# |    value_loss           | 0.000904    |
# -----------------------------------------
# Eval num_timesteps=69168, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 500        |
# |    mean_reward          | 500        |
# | time/                   |            |
# |    total_timesteps      | 69168      |
# | train/                  |            |
# |    approx_kl            | 0.01562633 |
# |    clip_fraction        | 0.164      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.49      |
# |    explained_variance   | -0.0204    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00943    |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.000579  |
# |    value_loss           | 0.000493   |
# ----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 2074  |
# |    iterations      | 34    |
# |    time_elapsed    | 33    |
# |    total_timesteps | 69632 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2077        |
# |    iterations           | 35          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009566469 |
# |    clip_fraction        | 0.0966      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | -0.0277     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00866    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00193    |
# |    value_loss           | 0.000445    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2079        |
# |    iterations           | 36          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.004191059 |
# |    clip_fraction        | 0.0788      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | -0.0753     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00989    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00199    |
# |    value_loss           | 0.000297    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2076        |
# |    iterations           | 37          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.009429084 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | -0.148      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0132     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.000534   |
# |    value_loss           | 0.000194    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2075        |
# |    iterations           | 38          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009680215 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.425      |
# |    explained_variance   | 0.031       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0207     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00486    |
# |    value_loss           | 0.000141    |
# -----------------------------------------
# Eval num_timesteps=79168, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 500          |
# |    mean_reward          | 500          |
# | time/                   |              |
# |    total_timesteps      | 79168        |
# | train/                  |              |
# |    approx_kl            | 0.0052770544 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.45        |
# |    explained_variance   | 0.0491       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0261      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000157    |
# |    value_loss           | 0.000113     |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 2056  |
# |    iterations      | 39    |
# |    time_elapsed    | 38    |
# |    total_timesteps | 79872 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2048        |
# |    iterations           | 40          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006622317 |
# |    clip_fraction        | 0.0807      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.467      |
# |    explained_variance   | -0.118      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00788    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00105    |
# |    value_loss           | 9.74e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2043        |
# |    iterations           | 41          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.015465166 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.437      |
# |    explained_variance   | -0.152      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00503     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.000156   |
# |    value_loss           | 6.29e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2041        |
# |    iterations           | 42          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.008199992 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.432      |
# |    explained_variance   | -0.109      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0101      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.000742    |
# |    value_loss           | 4.87e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2041        |
# |    iterations           | 43          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008407997 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.392      |
# |    explained_variance   | -0.0984     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00165     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00325     |
# |    value_loss           | 3.73e-05    |
# -----------------------------------------
# Eval num_timesteps=89168, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 500          |
# |    mean_reward          | 500          |
# | time/                   |              |
# |    total_timesteps      | 89168        |
# | train/                  |              |
# |    approx_kl            | 0.0073615266 |
# |    clip_fraction        | 0.0651       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.386       |
# |    explained_variance   | -0.142       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0272      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 2.99e-05     |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 2025  |
# |    iterations      | 44    |
# |    time_elapsed    | 44    |
# |    total_timesteps | 90112 |
# ------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2024       |
# |    iterations           | 45         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.00921625 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.384     |
# |    explained_variance   | -0.282     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00315    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.00272   |
# |    value_loss           | 3.64e-05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2026        |
# |    iterations           | 46          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008071465 |
# |    clip_fraction        | 0.0999      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.383      |
# |    explained_variance   | -0.122      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0263      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 1.74e-05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2029       |
# |    iterations           | 47         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.02174711 |
# |    clip_fraction        | 0.181      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.445     |
# |    explained_variance   | -0.227     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00203   |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.00633   |
# |    value_loss           | 2.29e-05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2032        |
# |    iterations           | 48          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.022623371 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.435      |
# |    explained_variance   | -0.399      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000901   |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00769    |
# |    value_loss           | 7.19e-06    |
# -----------------------------------------
# Eval num_timesteps=99168, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 500         |
# |    mean_reward          | 500         |
# | time/                   |             |
# |    total_timesteps      | 99168       |
# | train/                  |             |
# |    approx_kl            | 0.009475971 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.378      |
# |    explained_variance   | -0.372      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.018       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00696    |
# |    value_loss           | 1.51e-05    |
# -----------------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 2023   |
# |    iterations      | 49     |
# |    time_elapsed    | 49     |
# |    total_timesteps | 100352 |
# -------------------------------

# %% [markdown]
# ### Using an Alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', environment, tensorboard_log=log_path)

# %%
model.learn(total_timesteps=20000)

# %%
DQN.load
# Out:
# <bound method BaseAlgorithm.load of <class 'stable_baselines3.dqn.dqn.DQN'>>
