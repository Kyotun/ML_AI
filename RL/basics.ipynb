# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment = 'CartPole-v1'
env = gym.make(environment)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset() #Initial set of observations
    done = False
    score = 0
    
    while not done:
        env.render() #View the graphical representation of environment
        action = env.action_space.sample()#Generate random actions
        # Two actions possible -> push left / right
        
        # env.observation_space
        # Observation_space -> Position, Velocity of Cart ; Pole Angle and Agular Velocity
        # These make 4 info, in other words Box(4)
        
        n_state, reward, done, info , extra_info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
env.close()
# Out:
# Episode:1 Score:22.0
# Episode:2 Score:16.0
# Episode:3 Score:24.0
# Episode:4 Score:35.0
# Episode:5 Score:28.0
# /Users/kyotun/anaconda3/lib/python3.11/site-packages/gym/envs/classic_control/cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("CartPole-v1", render_mode="rgb_array")
#   gym.logger.warn(

# %%
#Create/Make the directories
log_path = os.path.join('Training', 'Logs')
log_path
# Out:
# 'Training/Logs'

# %%
env = gym.make(environment)
#Wrapped the environment inside the DummyVecEnv
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# /Users/kyotun/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device

# %%
#Timesteps depend on the complexity of the environment
model.learn(total_timesteps=200000)
# Out:
# Logging to Training/Logs/PPO_5
# -----------------------------
# | time/              |      |
# |    fps             | 5687 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3791         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0076872725 |
# |    clip_fraction        | 0.0763       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | -0.00323     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.43         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 55.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3493        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009955885 |
# |    clip_fraction        | 0.0765      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.664      |
# |    explained_variance   | 0.0943      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 34          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3358         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0092512425 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.632       |
# |    explained_variance   | 0.27         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.5         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.022       |
# |    value_loss           | 46.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3273        |
# |    iterations           | 5           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008755958 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.2        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 58.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3222        |
# |    iterations           | 6           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008350451 |
# |    clip_fraction        | 0.0909      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.598      |
# |    explained_variance   | 0.513       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 58.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3186        |
# |    iterations           | 7           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008695473 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.588      |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17          |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 53.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3163        |
# |    iterations           | 8           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007473262 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.42        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 32.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3144         |
# |    iterations           | 9            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0065294295 |
# |    clip_fraction        | 0.0591       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.575       |
# |    explained_variance   | 0.781        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.17         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00826     |
# |    value_loss           | 42.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3129         |
# |    iterations           | 10           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0030831941 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.561       |
# |    explained_variance   | 0.566        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.2         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00367     |
# |    value_loss           | 54.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3105        |
# |    iterations           | 11          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.003992449 |
# |    clip_fraction        | 0.0416      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.776       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 18.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3066        |
# |    iterations           | 12          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008143178 |
# |    clip_fraction        | 0.086       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.545      |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.841       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00683    |
# |    value_loss           | 12.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3047        |
# |    iterations           | 13          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008855428 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | -0.00335    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.07        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00546    |
# |    value_loss           | 25.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3031         |
# |    iterations           | 14           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0072105797 |
# |    clip_fraction        | 0.0614       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | -0.567       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.146        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 3.16         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3029         |
# |    iterations           | 15           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0055319658 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 0.0961       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0605       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 1.8          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3017         |
# |    iterations           | 16           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0049871393 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.514       |
# |    explained_variance   | 0.209        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0735       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000243    |
# |    value_loss           | 1.13         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3015        |
# |    iterations           | 17          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007377186 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.513      |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00152    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00374    |
# |    value_loss           | 0.706       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3013         |
# |    iterations           | 18           |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0040455647 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.52        |
# |    explained_variance   | -0.00145     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0114       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000693    |
# |    value_loss           | 0.431        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2999       |
# |    iterations           | 19         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00825576 |
# |    clip_fraction        | 0.0764     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.508     |
# |    explained_variance   | 0.893      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0299     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0114    |
# |    value_loss           | 0.261      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2999         |
# |    iterations           | 20           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0026808036 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.511       |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00596      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 0.162        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2997         |
# |    iterations           | 21           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0068203155 |
# |    clip_fraction        | 0.0551       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.511       |
# |    explained_variance   | 0.585        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0264      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00514     |
# |    value_loss           | 0.0988       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3000        |
# |    iterations           | 22          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.006345035 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.521      |
# |    explained_variance   | 0.44        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0146     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00675    |
# |    value_loss           | 0.0658      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3001         |
# |    iterations           | 23           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0059501925 |
# |    clip_fraction        | 0.0596       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.513       |
# |    explained_variance   | 0.186        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00546     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0044      |
# |    value_loss           | 0.0409       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2990        |
# |    iterations           | 24          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.004242769 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.508      |
# |    explained_variance   | 0.0223      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00449     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00177    |
# |    value_loss           | 0.0245      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2976         |
# |    iterations           | 25           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0033770627 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.54        |
# |    explained_variance   | -0.0359      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00163      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 0.0158       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2970         |
# |    iterations           | 26           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0039286697 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.514       |
# |    explained_variance   | -0.0298      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00902      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 0.0105       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2964         |
# |    iterations           | 27           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0035437122 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.519       |
# |    explained_variance   | 0.0139       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0073      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000325    |
# |    value_loss           | 0.00695      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2962         |
# |    iterations           | 28           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0026380748 |
# |    clip_fraction        | 0.00786      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.51        |
# |    explained_variance   | -0.0417      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00101     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000529    |
# |    value_loss           | 0.00427      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2961        |
# |    iterations           | 29          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.006966647 |
# |    clip_fraction        | 0.0622      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.505      |
# |    explained_variance   | -0.0211     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0333     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00523    |
# |    value_loss           | 0.00304     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2962         |
# |    iterations           | 30           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0016505371 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.487       |
# |    explained_variance   | -0.0819      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0102       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 3.16e-07     |
# |    value_loss           | 0.00202      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2962        |
# |    iterations           | 31          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.003786482 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.507      |
# |    explained_variance   | -0.0452     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00951    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00321    |
# |    value_loss           | 0.00136     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2964        |
# |    iterations           | 32          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004896032 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | 0.00764     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0166     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00341    |
# |    value_loss           | 0.000922    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2966        |
# |    iterations           | 33          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.005586162 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.503      |
# |    explained_variance   | -0.0876     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00567    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00171    |
# |    value_loss           | 0.000651    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2969         |
# |    iterations           | 34           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0041746474 |
# |    clip_fraction        | 0.055        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.511       |
# |    explained_variance   | 0.0454       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.01        |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 0.00045      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2970        |
# |    iterations           | 35          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.004156138 |
# |    clip_fraction        | 0.0264      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.484      |
# |    explained_variance   | -0.0237     |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0057     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.000569   |
# |    value_loss           | 0.00032     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2972         |
# |    iterations           | 36           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0047757467 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.496       |
# |    explained_variance   | -0.26        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00717     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 0.000227     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2974         |
# |    iterations           | 37           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0029109572 |
# |    clip_fraction        | 0.0411       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.469       |
# |    explained_variance   | -0.31        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000839     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 0.000162     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2976         |
# |    iterations           | 38           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0036234641 |
# |    clip_fraction        | 0.0327       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.453       |
# |    explained_variance   | -0.0705      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.017       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00182     |
# |    value_loss           | 0.000128     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2978          |
# |    iterations           | 39            |
# |    time_elapsed         | 26            |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00022166889 |
# |    clip_fraction        | 0.0103        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.465        |
# |    explained_variance   | -0.168        |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00332      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | 0.000649      |
# |    value_loss           | 8.18e-05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2979         |
# |    iterations           | 40           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0007216426 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.458       |
# |    explained_variance   | 0.0529       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00281     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000441    |
# |    value_loss           | 5.75e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2981         |
# |    iterations           | 41           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0030333407 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.437       |
# |    explained_variance   | 0.0818       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00534      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 3.94e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2982         |
# |    iterations           | 42           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0029846188 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.442       |
# |    explained_variance   | -0.0913      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000207     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 3.1e-05      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2982        |
# |    iterations           | 43          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.003464248 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.405      |
# |    explained_variance   | -0.168      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0105      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00243    |
# |    value_loss           | 2e-05       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2983         |
# |    iterations           | 44           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0021146736 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.422       |
# |    explained_variance   | -0.147       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00377     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000217    |
# |    value_loss           | 1.51e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2985         |
# |    iterations           | 45           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0025921115 |
# |    clip_fraction        | 0.0225       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.416       |
# |    explained_variance   | 0.0365       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0042       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00133     |
# |    value_loss           | 1.4e-05      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2986         |
# |    iterations           | 46           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0037275413 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.404       |
# |    explained_variance   | 0.244        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00631     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000714    |
# |    value_loss           | 8.39e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2987         |
# |    iterations           | 47           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0022717465 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.407       |
# |    explained_variance   | 0.268        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00192      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000441    |
# |    value_loss           | 8.01e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2988        |
# |    iterations           | 48          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.003392732 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.411      |
# |    explained_variance   | 0.347       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00455    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.000276    |
# |    value_loss           | 4.78e-06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2989       |
# |    iterations           | 49         |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.00208917 |
# |    clip_fraction        | 0.0189     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.414     |
# |    explained_variance   | 0.365      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00256   |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.000803  |
# |    value_loss           | 4.38e-06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2989        |
# |    iterations           | 50          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.003338799 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.389      |
# |    explained_variance   | 0.276       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00251    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00195    |
# |    value_loss           | 3.63e-06    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2986          |
# |    iterations           | 51            |
# |    time_elapsed         | 34            |
# |    total_timesteps      | 104448        |
# | train/                  |               |
# |    approx_kl            | 0.00075135793 |
# |    clip_fraction        | 0.0128        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.38         |
# |    explained_variance   | 0.125         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000798      |
# |    n_updates            | 500           |
# |    policy_gradient_loss | -0.00119      |
# |    value_loss           | 2.39e-06      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2988        |
# |    iterations           | 52          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.001977481 |
# |    clip_fraction        | 0.0258      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.376      |
# |    explained_variance   | 0.371       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000199    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | 8.5e-06     |
# |    value_loss           | 2.21e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2989         |
# |    iterations           | 53           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0030515622 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.346       |
# |    explained_variance   | 0.172        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00119      |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 1.84e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2990         |
# |    iterations           | 54           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0017170731 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.339       |
# |    explained_variance   | 0.527        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00122      |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.000495    |
# |    value_loss           | 2.33e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2991         |
# |    iterations           | 55           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0016335533 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.319       |
# |    explained_variance   | 0.521        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00197     |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.000628    |
# |    value_loss           | 1.23e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2987         |
# |    iterations           | 56           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 0.0027476083 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.323       |
# |    explained_variance   | 0.457        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000189     |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -0.000708    |
# |    value_loss           | 8.56e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2986         |
# |    iterations           | 57           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0021977425 |
# |    clip_fraction        | 0.0265       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.302       |
# |    explained_variance   | 0.496        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00548     |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 4.35e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2987        |
# |    iterations           | 58          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.001635995 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.286      |
# |    explained_variance   | 0.556       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00534     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 2.12e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2987         |
# |    iterations           | 59           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0015511919 |
# |    clip_fraction        | 0.015        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.296       |
# |    explained_variance   | 0.709        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00319     |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.000867    |
# |    value_loss           | 1.16e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2989         |
# |    iterations           | 60           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 0.0025546183 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.297       |
# |    explained_variance   | 0.619        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0284      |
# |    n_updates            | 590          |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 7.18e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2990         |
# |    iterations           | 61           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0020675007 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.292       |
# |    explained_variance   | 0.437        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0186      |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00165     |
# |    value_loss           | 1.87e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2992        |
# |    iterations           | 62          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.006039166 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.284      |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0011     |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00636    |
# |    value_loss           | 6.5e-07     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2993         |
# |    iterations           | 63           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 129024       |
# | train/                  |              |
# |    approx_kl            | 0.0016949238 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.265       |
# |    explained_variance   | 0.707        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00685     |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.000637    |
# |    value_loss           | 4.05e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2994         |
# |    iterations           | 64           |
# ...
# |    iterations           | 78            |
# |    time_elapsed         | 53            |
# |    total_timesteps      | 159744        |
# | train/                  |               |
# |    approx_kl            | 0.00080421526 |
# |    clip_fraction        | 0.0113        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.24         |
# |    explained_variance   | 0.636         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00484      |
# |    n_updates            | 770           |
# |    policy_gradient_loss | 0.000106      |
# |    value_loss           | 5.1e-06       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3005         |
# |    iterations           | 79           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 161792       |
# | train/                  |              |
# |    approx_kl            | 0.0024923652 |
# |    clip_fraction        | 0.0166       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.217       |
# |    explained_variance   | 0.75         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0133      |
# |    n_updates            | 780          |
# |    policy_gradient_loss | -0.000488    |
# |    value_loss           | 0.000168     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3005        |
# |    iterations           | 80          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.001705326 |
# |    clip_fraction        | 0.0199      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.231      |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00057    |
# |    n_updates            | 790         |
# |    policy_gradient_loss | 0.000368    |
# |    value_loss           | 3.33e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3006        |
# |    iterations           | 81          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.001450743 |
# |    clip_fraction        | 0.00894     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.221      |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00457     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -9.53e-05   |
# |    value_loss           | 3.59e-07    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3007       |
# |    iterations           | 82         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 167936     |
# | train/                  |            |
# |    approx_kl            | 0.00286989 |
# |    clip_fraction        | 0.0333     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.237     |
# |    explained_variance   | 0.688      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00391    |
# |    n_updates            | 810        |
# |    policy_gradient_loss | 2.36e-05   |
# |    value_loss           | 2.48e-07   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3008        |
# |    iterations           | 83          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.003978073 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.235      |
# |    explained_variance   | 0.777       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00241    |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 2.6e-07     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3009         |
# |    iterations           | 84           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0008697295 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.204       |
# |    explained_variance   | 0.746        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0012       |
# |    n_updates            | 830          |
# |    policy_gradient_loss | 0.000154     |
# |    value_loss           | 1.82e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3010         |
# |    iterations           | 85           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0012349052 |
# |    clip_fraction        | 0.0206       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.223       |
# |    explained_variance   | 0.703        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00149      |
# |    n_updates            | 840          |
# |    policy_gradient_loss | 0.00101      |
# |    value_loss           | 1.69e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3010         |
# |    iterations           | 86           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0029205466 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.234       |
# |    explained_variance   | 0.784        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0203       |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 5.03e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3011         |
# |    iterations           | 87           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0015350915 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.225       |
# |    explained_variance   | 0.761        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00255     |
# |    n_updates            | 860          |
# |    policy_gradient_loss | 0.00063      |
# |    value_loss           | 3.87e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3011         |
# |    iterations           | 88           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0036008158 |
# |    clip_fraction        | 0.0323       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.228       |
# |    explained_variance   | 0.794        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00771      |
# |    n_updates            | 870          |
# |    policy_gradient_loss | 0.000343     |
# |    value_loss           | 2.47e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3012         |
# |    iterations           | 89           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0008092826 |
# |    clip_fraction        | 0.0157       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.233       |
# |    explained_variance   | 0.736        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00524     |
# |    n_updates            | 880          |
# |    policy_gradient_loss | 0.000619     |
# |    value_loss           | 2.77e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3012         |
# |    iterations           | 90           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0020175013 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.23        |
# |    explained_variance   | 0.755        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00437     |
# |    n_updates            | 890          |
# |    policy_gradient_loss | 0.000145     |
# |    value_loss           | 8.36e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3013         |
# |    iterations           | 91           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0031037452 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.217       |
# |    explained_variance   | 0.771        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00763      |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 4.15e-07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3014          |
# |    iterations           | 92            |
# |    time_elapsed         | 62            |
# |    total_timesteps      | 188416        |
# | train/                  |               |
# |    approx_kl            | 0.00023411421 |
# |    clip_fraction        | 0.0117        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.222        |
# |    explained_variance   | 0.636         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00318      |
# |    n_updates            | 910           |
# |    policy_gradient_loss | 0.00108       |
# |    value_loss           | 5.68e-05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3015         |
# |    iterations           | 93           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0012409621 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | 0.675        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000748    |
# |    n_updates            | 920          |
# |    policy_gradient_loss | -0.000332    |
# |    value_loss           | 7.62e-08     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3015        |
# |    iterations           | 94          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.005276059 |
# |    clip_fraction        | 0.0546      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.259      |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0344     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00246    |
# |    value_loss           | 1.25e-07    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3016        |
# |    iterations           | 95          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.005015581 |
# |    clip_fraction        | 0.0473      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.24       |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00741    |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00297    |
# |    value_loss           | 1.37e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3016         |
# |    iterations           | 96           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0005968945 |
# |    clip_fraction        | 0.00957      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.24        |
# |    explained_variance   | 0.714        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00169      |
# |    n_updates            | 950          |
# |    policy_gradient_loss | 7.44e-05     |
# |    value_loss           | 1.11e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3017        |
# |    iterations           | 97          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.005208684 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.243      |
# |    explained_variance   | 0.671       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00696    |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00199    |
# |    value_loss           | 8.95e-08    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3018        |
# |    iterations           | 98          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.004713521 |
# |    clip_fraction        | 0.0255      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.225      |
# |    explained_variance   | 0.717       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00931    |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.00081    |
# |    value_loss           | 5.41e-07    |
# -----------------------------------------

# %% [markdown]
# ### Save and Reload Model

# %%
PPO_Path = os.path.join('Training', 'Saved Models', 'PPO_Model_Cartpole')

# %%
model.save(PPO_Path)

# %%
#Delete the model and reload it
del model

# %%
model = PPO.load(PPO_Path, env=env)

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training/Logs/PPO_6
# -----------------------------
# | time/              |      |
# |    fps             | 6177 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4070         |
# |    iterations           | 2            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0043387786 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.24        |
# |    explained_variance   | 0.696        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00272     |
# |    n_updates            | 990          |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 4.93e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3652         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0032235351 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.242       |
# |    explained_variance   | 0.695        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00499     |
# |    n_updates            | 1000         |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 7.02e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3484         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0027110563 |
# |    clip_fraction        | 0.0119       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | 0.654        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0133      |
# |    n_updates            | 1010         |
# |    policy_gradient_loss | -0.000429    |
# |    value_loss           | 6.45e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3377         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0034706176 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.23        |
# |    explained_variance   | 0.725        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00291      |
# |    n_updates            | 1020         |
# |    policy_gradient_loss | -8.82e-05    |
# |    value_loss           | 3.36e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3319         |
# |    iterations           | 6            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0006081098 |
# |    clip_fraction        | 0.0123       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.242       |
# |    explained_variance   | 0.726        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00746      |
# |    n_updates            | 1030         |
# |    policy_gradient_loss | 0.000645     |
# |    value_loss           | 6.73e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3280         |
# |    iterations           | 7            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0013970723 |
# |    clip_fraction        | 0.0129       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.24        |
# |    explained_variance   | 0.674        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00199      |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | -0.00016     |
# |    value_loss           | 4.94e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3245         |
# |    iterations           | 8            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0003208484 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.251       |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00482      |
# |    n_updates            | 1050         |
# |    policy_gradient_loss | 3.75e-06     |
# |    value_loss           | 1.42e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3226        |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.002646123 |
# |    clip_fraction        | 0.0166      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.246      |
# |    explained_variance   | 0.586       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00259    |
# |    n_updates            | 1060        |
# |    policy_gradient_loss | 0.000518    |
# |    value_loss           | 8.26e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3212         |
# |    iterations           | 10           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0008648663 |
# |    clip_fraction        | 0.0181       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.24        |
# |    explained_variance   | 0.573        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000483     |
# |    n_updates            | 1070         |
# |    policy_gradient_loss | 0.000204     |
# |    value_loss           | 2.4e-06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3200         |
# |    iterations           | 11           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0049682595 |
# |    clip_fraction        | 0.0583       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.25        |
# |    explained_variance   | 0.462        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00061     |
# |    n_updates            | 1080         |
# |    policy_gradient_loss | -0.00079     |
# |    value_loss           | 9.67e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3188         |
# |    iterations           | 12           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0009243332 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.252       |
# |    explained_variance   | 0.684        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000943    |
# |    n_updates            | 1090         |
# |    policy_gradient_loss | -0.000305    |
# |    value_loss           | 2.37e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3178         |
# |    iterations           | 13           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0011987045 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.249       |
# |    explained_variance   | 0.638        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000984     |
# |    n_updates            | 1100         |
# |    policy_gradient_loss | 0.000284     |
# |    value_loss           | 1.49e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3169        |
# |    iterations           | 14          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.001894532 |
# |    clip_fraction        | 0.0386      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.259      |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0112      |
# |    n_updates            | 1110        |
# |    policy_gradient_loss | -0.000917   |
# |    value_loss           | 1.16e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3164         |
# |    iterations           | 15           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0003917545 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.248       |
# |    explained_variance   | 0.667        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000434     |
# |    n_updates            | 1120         |
# |    policy_gradient_loss | 0.000241     |
# |    value_loss           | 1.57e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3159        |
# |    iterations           | 16          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.002711413 |
# |    clip_fraction        | 0.0407      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.24       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00433     |
# |    n_updates            | 1130        |
# |    policy_gradient_loss | -0.00124    |
# |    value_loss           | 9.82e-08    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3155         |
# |    iterations           | 17           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0016224312 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.242       |
# |    explained_variance   | 0.703        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.005        |
# |    n_updates            | 1140         |
# |    policy_gradient_loss | -0.000229    |
# |    value_loss           | 3.43e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3152         |
# |    iterations           | 18           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0019818936 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.236       |
# |    explained_variance   | 0.617        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00688     |
# |    n_updates            | 1150         |
# |    policy_gradient_loss | -0.000444    |
# |    value_loss           | 1.1e-05      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3148       |
# |    iterations           | 19         |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.00245685 |
# |    clip_fraction        | 0.0153     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.228     |
# |    explained_variance   | 0.752      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00136   |
# |    n_updates            | 1160       |
# |    policy_gradient_loss | -0.000162  |
# |    value_loss           | 2.87e-07   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3145         |
# |    iterations           | 20           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0015431873 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | 0.529        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00321     |
# |    n_updates            | 1170         |
# |    policy_gradient_loss | 0.00015      |
# |    value_loss           | 4.04e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3142         |
# |    iterations           | 21           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0008031067 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.233       |
# |    explained_variance   | 0.734        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0143       |
# |    n_updates            | 1180         |
# |    policy_gradient_loss | 0.000162     |
# |    value_loss           | 5.84e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3138         |
# |    iterations           | 22           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0023362893 |
# |    clip_fraction        | 0.0309       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.23        |
# |    explained_variance   | 0.733        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000918     |
# |    n_updates            | 1190         |
# |    policy_gradient_loss | -0.000951    |
# |    value_loss           | 4.61e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3135         |
# |    iterations           | 23           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0024658865 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.222       |
# |    explained_variance   | 0.698        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00814     |
# |    n_updates            | 1200         |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 1.52e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3133         |
# |    iterations           | 24           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0039561056 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.254       |
# |    explained_variance   | 0.761        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000794     |
# |    n_updates            | 1210         |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 1.41e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3131        |
# |    iterations           | 25          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.002454781 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.229      |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0014     |
# |    n_updates            | 1220        |
# |    policy_gradient_loss | -0.000531   |
# |    value_loss           | 1.17e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3130         |
# |    iterations           | 26           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0014630696 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.241       |
# |    explained_variance   | 0.716        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00253      |
# |    n_updates            | 1230         |
# |    policy_gradient_loss | 0.000561     |
# |    value_loss           | 6.34e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3129        |
# |    iterations           | 27          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.002917144 |
# |    clip_fraction        | 0.0214      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.25       |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00211     |
# |    n_updates            | 1240        |
# |    policy_gradient_loss | 0.000144    |
# |    value_loss           | 1.69e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3127         |
# |    iterations           | 28           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0006483996 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.251       |
# |    explained_variance   | 0.689        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00324     |
# |    n_updates            | 1250         |
# |    policy_gradient_loss | -0.000952    |
# |    value_loss           | 1.05e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3113          |
# |    iterations           | 29            |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 59392         |
# | train/                  |               |
# |    approx_kl            | 0.00078807876 |
# |    clip_fraction        | 0.0153        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.252        |
# |    explained_variance   | 0.693         |
# |    learning_rate        | 0.0003        |
# |    loss                 | -0.00139      |
# |    n_updates            | 1260          |
# |    policy_gradient_loss | 0.000203      |
# |    value_loss           | 5.02e-08      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3111        |
# |    iterations           | 30          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.002830857 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.251      |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00116    |
# |    n_updates            | 1270        |
# |    policy_gradient_loss | -0.00125    |
# |    value_loss           | 3.08e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3111         |
# |    iterations           | 31           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0030343072 |
# |    clip_fraction        | 0.0243       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.221       |
# |    explained_variance   | 0.683        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00398     |
# |    n_updates            | 1280         |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 2.65e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3110         |
# |    iterations           | 32           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0008462852 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.231       |
# |    explained_variance   | 0.625        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00384     |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | -0.000133    |
# |    value_loss           | 5.63e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3109         |
# |    iterations           | 33           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0007884222 |
# |    clip_fraction        | 0.0412       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.242       |
# |    explained_variance   | 0.751        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00691      |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | -0.000594    |
# |    value_loss           | 2.52e-05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3108          |
# |    iterations           | 34            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00088015664 |
# |    clip_fraction        | 0.0244        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.239        |
# |    explained_variance   | 0.62          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.00235       |
# |    n_updates            | 1310          |
# |    policy_gradient_loss | -0.000963     |
# |    value_loss           | 4.02e-08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3105         |
# |    iterations           | 35           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0011411909 |
# |    clip_fraction        | 0.013        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | 0.772        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0034      |
# |    n_updates            | 1320         |
# |    policy_gradient_loss | 0.000807     |
# |    value_loss           | 4.86e-08     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3105        |
# |    iterations           | 36          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.006473476 |
# |    clip_fraction        | 0.0686      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.251      |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0152     |
# |    n_updates            | 1330        |
# |    policy_gradient_loss | -0.00439    |
# |    value_loss           | 1.39e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3105         |
# |    iterations           | 37           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0040521333 |
# |    clip_fraction        | 0.0342       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.263       |
# |    explained_variance   | 0.661        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00354     |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 1.79e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3104        |
# |    iterations           | 38          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.005723428 |
# |    clip_fraction        | 0.0564      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.269      |
# |    explained_variance   | 0.711       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00103     |
# |    n_updates            | 1350        |
# |    policy_gradient_loss | -0.00366    |
# |    value_loss           | 1.49e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3104         |
# |    iterations           | 39           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0019983612 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.227       |
# |    explained_variance   | 0.654        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00674     |
# |    n_updates            | 1360         |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 9.87e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3103         |
# |    iterations           | 40           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0014519263 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.242       |
# |    explained_variance   | 0.762        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00605      |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.000455    |
# |    value_loss           | 1.03e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3101         |
# |    iterations           | 41           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0037035127 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.255       |
# |    explained_variance   | 0.571        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00127      |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.0037      |
# |    value_loss           | 5.99e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3101         |
# |    iterations           | 42           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0016049673 |
# |    clip_fraction        | 0.0121       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.257       |
# |    explained_variance   | 0.686        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00283      |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | 0.000274     |
# |    value_loss           | 7.16e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3090         |
# |    iterations           | 43           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0037471435 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.233       |
# |    explained_variance   | 0.677        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00331     |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -0.00264     |
# |    value_loss           | 7.12e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3088         |
# |    iterations           | 44           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0028259163 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.217       |
# |    explained_variance   | 0.671        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00285     |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 2.57e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3085         |
# |    iterations           | 45           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0014475363 |
# |    clip_fraction        | 0.00845      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.242       |
# |    explained_variance   | 0.769        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0025       |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | 9.59e-05     |
# |    value_loss           | 1.47e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3084         |
# |    iterations           | 46           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0033521606 |
# |    clip_fraction        | 0.0224       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.238       |
# |    explained_variance   | 0.772        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0114       |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | 0.000156     |
# |    value_loss           | 7.47e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3084         |
# |    iterations           | 47           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0011009399 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | 0.757        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00534     |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -6.14e-05    |
# |    value_loss           | 4.36e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3081         |
# |    iterations           | 48           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0010271864 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.257       |
# |    explained_variance   | 0.679        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0116      |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | -0.00045     |
# |    value_loss           | 3.35e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3077         |
# |    iterations           | 49           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0016716601 |
# |    clip_fraction        | 0.0127       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.235       |
# |    explained_variance   | 0.75         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00668     |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 1.22e-07     |
# ------------------------------------------
